# %%
#TODO nao estou tratanto o caso do OR
#TODO nao nao trado caso o usario queira colocar um intervalor tipo assim 30<=var<=40

# %%
shared_base_name = "RQ1_complete_scenarios"

# %%
variables_config_path = "res/variables_config.json"

shared_base_path = f"res/outcome/shared_scenarios/{shared_base_name}.json"
analyzed_scenarios_path ="res/analyzed_scenario_process.json"

# %%
import json
import pandas as pd
from pyparsing import Word, alphas, nums, oneOf, infixNotation, opAssoc, ParserElement
from sympy import sympify
from sympy.logic.boolalg import to_dnf
import re
# Configurações para exibir todas as colunas
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_desired_scenario(file_path=analyzed_scenarios_path):
    # Ler o arquivo JSON
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Pegar o valor da chave 'desired'
    desired_scenarios = data.get('desired')
    # desired_scenario_name = next(iter(desired_scenario))
    # Exibir o valor

    # print("Desired scenario: ", desired_scenario)
    
    return desired_scenarios

# get_desired_scenario()

# %%
def load_variable_ranges(file_path = variables_config_path):
    with open(file_path, 'r') as file:
        json_data = file.read()
    variable_ranges = json.loads(json_data)
    
    # print("Variable ranges: ", {var['name']: var for var in variable_ranges})

    return {var['name']: var for var in variable_ranges}

# load_variable_ranges()

# %%
def get_shared_scenarios(file_path = shared_base_path):
    # Ler o arquivo JSON
    with open(file_path, 'r') as file:
        shared_scenarios = json.load(file)
    return shared_scenarios

# %%
def get_Given(scenario):
   # print("Scenario: ",scenario)
    scenario_name = next(iter(scenario))
    given_exp=scenario[scenario_name]["Given"]
  #  print("Given: ",given_exp)
    return given_exp

# print(get_Given(get_desired_scenario()))

# %%
def get_Do(scenario):
    scenario_name = next(iter(scenario))  
    do_exp=scenario[scenario_name]["Do"]
    # print("Do: ",do_exp)
    return do_exp

# %%
def get_When(scenario):
    scenario_name = next(iter(scenario))  
    when_exp=scenario[scenario_name]["When"]
    # print("When: ", when_exp)
    return when_exp

# print(get_When(get_desired_scenario()))

# %%
def get_Then(scenario):
    scenario_name = next(iter(scenario)) 
    then_exp=scenario[scenario_name]["Then"]
    # print("Then: ", then_exp)
    return then_exp

# print(get_Then(get_desired_scenario()))

# %%
def get_precondition(scenario):
    print("Scenario: ", scenario)
    given_exp=get_Given(scenario)
    when_exp=get_When(scenario)

    precond = "{} AND {}".format(given_exp, when_exp)
    # print(f"Precondition: {precond}")
    return precond

# print(get_precondition(get_desired_scenario()))

# %%
def get_postcondition(scenario):

    postcond =  get_Then(scenario)
    # print(f"Postcondition: {postcond}")
    return postcond

# print(get_postcondition(get_desired_scenario()))

# %%
def logical_expression_settings():
    # Configurar pyparsing para ignorar espaços em branco
    ParserElement.enablePackrat()

    # Definir elementos básicos da expressão
    identifier = Word(alphas, alphas + nums + "_")
    number = Word(nums)

    # Definir operadores de comparação
    comparison_operator = oneOf("<= >= < > == !=")

    # Definir expressão básica
    operand = identifier | number

    # Definir expressão lógica
    logical_expr = infixNotation(operand,
        [
            (comparison_operator, 2, opAssoc.LEFT),
            ("AND", 2, opAssoc.LEFT),
            ("OR", 2, opAssoc.LEFT),
        ])

    return logical_expr


def extract_leaves(parsed_expr):
    """Extrai folhas de uma expressão lógica analisada."""
    
    if isinstance(parsed_expr, str):
        return []
    elif len(parsed_expr) == 3 and parsed_expr[1] in ["<=", ">=", "<", ">", "==", "!="]:
        return [" ".join(parsed_expr)]
    else:
        leaves = []
        for sub_expr in parsed_expr:
            leaves.extend(extract_leaves(sub_expr))
        return leaves

# Exemplo de uso
# expression_scenario = "(((a <= 3 AND (b > 10 OR c == 10)) OR ((d != 5 AND e >= 20) OR f < 2)) AND ((g <= 7 OR h > 8) AND (i == 9 OR j != 3)))"
# expression_scenario = "(a <= 3 AND b > 10)"

# expression_scenario = get_Given(get_desired_scenario())

# parsed_expression = logical_expression_settings().parseString(expression_scenario, parseAll=True)

# print("Extracted Leafs:", extract_leaves(parsed_expression.asList()))

# %%
def list_to_indexed_dict(lst):
    """
    Transforms a list of strings into a dictionary with keys 'x1', 'x2', ..., 'xn'.
    
    Parameters:
    lst (list): List of strings.

    Returns:
    dict: Dictionary with keys 'x1', 'x2', ..., 'xn' and values from the original list.
    """
    return {f'x{i+1}': value for i, value in enumerate(lst)}

# Example usage
# lst = ['a <= 3', 'b > 10']
# map_dict = list_to_indexed_dict(extract_leaves(parsed_expression.asList()))
# print("Indexed Dict:", map_dict)

# %%
def replace_values_with_keys(string, dictionary):
    """
    Replaces occurrences of the dictionary values with the keys in the string.

    Parameters:
    string (str): The string where the replacements will be made.
    dictionary (dict): The dictionary with keys and values to be replaced.

    Returns:
    str: The string with values replaced by keys.
    """
    for key, value in dictionary.items():
        string = string.replace(value, key)
    return string

# indexed_scenario = replace_values_with_keys(expression_scenario, map_dict)
# print(indexed_scenario)

# %%
def replace_logical_operators(string, scenario_operators=False):
    """
    Substitui os operadores lógicos 'AND' por '&' e 'OR' por '|', ou vice-versa.

    Parâmetros:
    string (str): A string onde as substituições serão feitas.
    scenario_operators (bool): Se True, substitui '&' por 'AND' e '|' por 'OR'.
                               Se False, substitui 'AND' por '&' e 'OR' por '|'.

    Retorno:
    str: A string com os operadores lógicos substituídos.
    """
    if scenario_operators:
        return string.replace('&', 'AND').replace('|', 'OR')
    else:
        return string.replace('AND', '&').replace('OR', '|')



# indexed_scenario = replace_logical_operators(indexed_scenario)
# print("indexed_scenario:", indexed_scenario)

# %%
def _to_dnf(indexed_scenario):
    """
    Converts a logical expression to Disjunctive Normal Form (DNF).

    Parameters:
    indexed_scenario (str): The logical expression in string format with indexed variables.

    Returns:
    str: The logical expression in Disjunctive Normal Form.
    """
    # Convert the string to a symbolic expression
    logical_expression = sympify(indexed_scenario)

    # Convert the symbolic expression to Disjunctive Normal Form
    dnf_expr = to_dnf(logical_expression, simplify=True, force=True)

    return str(dnf_expr)

# Example usage
# dnf_expr = __to_dnf_expression(indexed_scenario)
# print(dnf_expr)

# %%
def revert_keys_to_values(string, dictionary):
    """
    Replaces occurrences of the dictionary keys with the values in the string.

    Parameters:
    string (str): The string where the replacements will be made.
    dictionary (dict): The dictionary with keys and values to be replaced.

    Returns:
    str: The string with the keys replaced by the original values.
    """
    # print("Dictionary: ", dictionary)
    for key, value in dictionary.items():
        string = re.sub(rf'\b{re.escape(key)}\b', value, string)    
        # string = string.replace(key, value)
    
    return string

# Example usage
# final_string = revert_keys_to_values(str(dnf_expr), map_dict)
# print(f"Final string with original values: {final_string}")

# %%
def to_dnf_expression(expression_scenario):

    parsed_expression = logical_expression_settings().parseString(expression_scenario, parseAll=True)
    # print("Parsed Expression:", parsed_expression)

    extracted_leaves=extract_leaves(parsed_expression.asList())
    # print("Extracted Leafs:", extracted_leaves)

    map_dict = list_to_indexed_dict(extracted_leaves)
    # print("Indexed Dict:", map_dict)

    indexed_scenario = replace_values_with_keys(expression_scenario, map_dict)
    # print("replaced values with keys:", indexed_scenario)

    indexed_scenario = replace_logical_operators(indexed_scenario)
    # print("indexed_scenario:", indexed_scenario)

    dnf_expr = _to_dnf(indexed_scenario)
    # print(dnf_expr)

    # Example usage
    dnf_expression = revert_keys_to_values(str(dnf_expr), map_dict)
    # print(f"Final string with original values: {dnf_expression}")

    dnf_expression=replace_logical_operators(dnf_expression, scenario_operators=True)
    # print(f"dnf_expression: {dnf_expression}")

    return dnf_expression

# %%
def parse_expression(leaf):
    """
    Parse the expression into its components: variable, operator, and value.
    """
    match = re.match(r"(\w+)\s*(>=|<=|>|<|==|!=)\s*(.+)", leaf)
    if match:
        variable, operator, value = match.groups()
        return variable, operator, value
    else:
        raise ValueError(f"Invalid expression format: {leaf}")

def get_expression_range(var_name, operator, value, min_val, max_val):
    """
    Determine the range of values that satisfy the expression.
    """
    value = float(value)
    if operator == '>=':
        return (value, max_val)
    elif operator == '<=':
        return (min_val, value)
    elif operator == '>':
        return (value + 1e-9, max_val)  # Adding a small value to make it exclusive
    elif operator == '<':
        return (min_val, value - 1e-9)  # Subtracting a small value to make it exclusive
    elif operator == '==':
        return (value, value)
    elif operator == '!=':
        return [(min_val, value - 1e-9), (value + 1e-9, max_val)]  # Returns two ranges
    else:
        raise ValueError(f"Unsupported operator: {operator}")

def calculate_jaccard_similarity(leaf1, leaf2, variable_ranges):
    """
    Calculate the Jaccard similarity between two expressions.
    The expressions should be of the format: "variable operator value".
    """
    try:
        var1, op1, val1 = parse_expression(leaf1)
        var2, op2, val2 = parse_expression(leaf2)
    except ValueError as e:
        print(e)
        return 0.0

    # Ensure the variable names are the same
    if var1 != var2:
        return 0.0

    # Get variable ranges
    var_info = variable_ranges.get(var1)
    if not var_info:
        print(f"Variable {var1} not found in ranges.")
        return 0.0

    min_val = var_info['min_value']
    max_val = var_info['max_value']

    # Get ranges for each expression
    range1 = get_expression_range(var1, op1, val1, min_val, max_val)
    range2 = get_expression_range(var2, op2, val2, min_val, max_val)

    def calculate_intersection_union(range1, range2):
        """
        Helper function to calculate intersection and union of two ranges.
        """
        if isinstance(range1, list):
            intersections = []
            for r1 in range1:
                if isinstance(range2, list):
                    for r2 in range2:
                        intersections.append((max(r1[0], r2[0]), min(r1[1], r2[1])))
                else:
                    intersections.append((max(r1[0], range2[0]), min(r1[1], range2[1])))
        else:
            if isinstance(range2, list):
                intersections = [(max(range1[0], r2[0]), min(range1[1], r2[1])) for r2 in range2]
            else:
                intersections = [(max(range1[0], range2[0]), min(range1[1], range2[1]))]
        
        valid_intersections = [r for r in intersections if r[0] <= r[1]]
        intersection_length = sum(r[1] - r[0] for r in valid_intersections)
        
        union_min = min(range1[0] if not isinstance(range1, list) else min(r[0] for r in range1),
                        range2[0] if not isinstance(range2, list) else min(r[0] for r in range2))
        union_max = max(range1[1] if not isinstance(range1, list) else max(r[1] for r in range1),
                        range2[1] if not isinstance(range2, list) else max(r[1] for r in range2))
        union_length = union_max - union_min
        
        return intersection_length, union_length

    # Calculate intersection and union considering the equality operator cases
    if op1 == '==' and op2 != '==':
        if isinstance(range2, list):
            range2_min, range2_max = min(range2[0][0], range2[1][0]), max(range2[0][1], range2[1][1])
            if range2_min <= range1[0] <= range2_max:
                intersection_length = 1
                union_length = range2_max - range2_min
            else:
                return 0.0
        else:
            if range2[0] <= range1[0] <= range2[1]:
                intersection_length = 1
                union_length = range2[1] - range2[0]
            else:
                return 0.0
    elif op2 == '==' and op1 != '==':
        if isinstance(range1, list):
            range1_min, range1_max = min(range1[0][0], range1[1][0]), max(range1[0][1], range1[1][1])
            if range1_min <= range2[0] <= range1_max:
                intersection_length = 1
                union_length = range1_max - range1_min
            else:
                return 0.0
        else:
            if range1[0] <= range2[0] <= range1[1]:
                intersection_length = 1
                union_length = range1[1] - range1[0]
            else:
                return 0.0
    elif op1 == '==' and op2 == '==':
        if val1 == val2:
            return 1.0
        else:
            return 0.0
    else:
        intersection_length, union_length = calculate_intersection_union(range1, range2)

    # Calculate the Jaccard similarity

    if union_length == 0:
        return 0.0
    similarity = intersection_length / union_length
    return round(similarity,5)

# # Load the variable ranges from the file
# variable_ranges_from_file = load_variable_ranges()

# # Test cases
# test_cases = [
#     # ("height == 30", "height <= 40"),  # equality with range
#     # ("height == 30", "height == 30"),  # equality with equality (same)
#     # ("height == 30", "height == 40"),  # equality with equality (different)
#     # ("height >= 30", "height <= 40"),  # range with range
#     # ("height != 30", "height <= 40"),  # inequality with range
#     # ("battery < 10", "battery < 11"),
#     # ("battery < 10", "battery > 11"),
#     # ("battery < 10", "battery > 0"),
#     # ("wind_speed <= 36", "wind_speed <= 360"),
#     # ("wind_speed <= 36", "wind_speed >= 0"),
#     ("wind_speed <= 36","wind_speed > 36")
#        # inequality with equality
# ]

# var_similarity_dict = {f"{expr1} vs {expr2}": calculate_jaccard_similarity(expr1, expr2, variable_ranges_from_file)
#            for expr1, expr2 in test_cases}

# # # Convert results to DataFrame and display
# # results_df = pd.DataFrame(results.items(), columns=["Test Case", "Similarity"])
# # results_df
# var_similarity_dict
# Out:
# {'wind_speed <= 36 vs wind_speed > 36': 0.0}

# %%
# calculate_jaccard_similarity('obstacle > 10', 'obstacle < 11', load_variable_ranges())

# %%
def local_similarity(leaf1, leaf2, variable_ranges_from_file):
    local_similarity = calculate_jaccard_similarity(leaf1, leaf2, variable_ranges_from_file)
    # print(f"Local similarity between {leaf1} vs {leaf2}: {local_similarity}")
    return local_similarity

# %%
def get_leafs(dnf):
    parsed_expression = logical_expression_settings().parseString(dnf, parseAll=True)
    # print("Parsed Expression:", parsed_expression)

    extracted_leaves=extract_leaves(parsed_expression.asList())
    # print("Extracted Leafs:", extracted_leaves)
    return extracted_leaves

# %%
def extract_variables(leafts):
    """
    Extracts the variable names from a list of leaf strings.

    Parameters:
    leaves (list): List of strings, each containing a variable, an operator, and a value.

    Returns:
    list: List of variable names.
    """
    variables = []
    for leaf in leafts:
        # Using regular expression to match the variable name at the beginning of the string
        match = re.match(r"([a-zA-Z_]\w*)\s*(==|!=|[<>]=?)\s*\d+", leaf)
        if match:
            variables.append(match.group(1))
    return variables

# %%
def tversky_similarity(vars1, vars2, alpha=1.0, beta=1.0):
    """
    Calculate the Tversky similarity between two sets of variables.
    
    Args:
    vars1 (list): First list of variables.
    vars2 (list): Second list of variables.
    alpha (float): Weight for the elements unique to vars1. Default is 1.0.
    beta (float): Weight for the elements unique to vars2. Default is 1.0.
    
    Returns:
    float: The Tversky similarity score.
    """
    set1 = set(vars1)
    set2 = set(vars2)
    
    intersection = len(set1 & set2)
    only_in_set1 = len(set1 - set2)
    only_in_set2 = len(set2 - set1)
    
    tversky_index = intersection / (intersection + alpha * only_in_set1 + beta * only_in_set2)
    
    return tversky_index

def penality(vars1, vars2, alpha=1.0, beta=1.0):
    return 1 - tversky_similarity(vars1, vars2, alpha, beta)

# %%
def intersection(vector1, vector2):
    """
    Find the intersection between two vectors of elements.
    
    Args:
    vector1 (list): First list of elements.
    vector2 (list): Second list of elements.
    
    Returns:
    list: A list containing the elements that are present in both vectors.
    """
    set1 = set(vector1)
    set2 = set(vector2)
    
    intersection = set1 & set2
    
    return list(intersection)

# %%
def pair_leaves(leaves1, leaves2):
    """
    Create pairs of leaves containing the same variable.
    
    Args:
    leaves1 (list): First list of leaves.
    leaves2 (list): Second list of leaves.
    
    Returns:
    list: A list of tuples, each containing a pair of leaves with the same variable.
    """
    pairs = []
    
    # Extract variable names from leaves
    def extract_variable(leaf):
        return leaf.split()[0]
    
    variables1 = {extract_variable(leaf): leaf for leaf in leaves1}
    variables2 = {extract_variable(leaf): leaf for leaf in leaves2}
    
    # Create pairs
    for var in variables1:
        if var in variables2:
            pairs.append((variables1[var], variables2[var]))
    
    return pairs

# %%
# funcao Mocked para similar os pesos.
def get_weights():
    # TODO: Implementar a lógica para obter os pesos com esse formato {'a': 0.75, 'b': 0.0, 'c': 0.0}
    return {} # Weight is considered 1 when variable is not present in the weights dictionary

weight_dict = get_weights()
# print("Weights:{}".format(weight_dict))

# %%
def extract_variable_similarity(local_similarity):
    """
    Extract variable names and their similarities from a dictionary of leaf pairs.
    
    Args:
    pairs_similarity (dict): A dictionary with tuples of leaf pairs as keys and similarity values as values.
    
    Returns:
    dict: A dictionary with variable names as keys and similarity values as values.
    """
    variable_similarity = {}
    
    for (leaf1, leaf2), similarity in local_similarity.items():
        variable = leaf1.split()[0]
        variable_similarity[variable] = similarity
    
    return variable_similarity

# %%
def similarity_global(local_similarity):
    weight_dict=get_weights()
    variable_similarity_dict=extract_variable_similarity(local_similarity)

    weighted_sum = 0
    total_weight = 0
    
    for var, similarity in variable_similarity_dict.items():
        weight = weight_dict.get(var, 1)
        weighted_sum += similarity * weight
        total_weight += weight

    if total_weight == 0:
        return 0  # Avoid division by zero
    
    weighted_average = weighted_sum / total_weight
    return weighted_average

# %%
def scenario_similarity(final_similarity_given,
                         final_similarity_when,
                           final_similarity_then,
                           weight_given=1.0,weight_when=1.0,weight_then=1.0):
    return (final_similarity_given * weight_given + final_similarity_when * weight_when + final_similarity_then * weight_then) / (weight_given + weight_when + weight_then)

# %%
def similarity(desired_scenario):
    given_dnf1=to_dnf_expression(get_Given(desired_scenario))
    when_dnf1=to_dnf_expression(get_When(desired_scenario))
    then_dnf1=to_dnf_expression(get_Then(desired_scenario))

    shared_scenarios = get_shared_scenarios()

    # Lista para armazenar os resultados
    results_to_df = []

    similarity_result = {} 
    for shared_scenario in shared_scenarios:

        # print("Desired Given DNF: ", given_dnf1)
        # print("Desired When DNF: ", when_dnf1)
        # print("Desired Then DNF: ", then_dnf1)
        # print("")

        given_leafs1=get_leafs(given_dnf1)
        when_leafs1=get_leafs(when_dnf1)
        then_leafs1=get_leafs(then_dnf1)

        # print("Leafs Given 1: ", given_leafs1)
        # print("Leafs When 1: ", when_leafs1)
        # print("Leafs Then 1: ", then_leafs1)

        given_variables1=extract_variables(given_leafs1)
        when_variables1=extract_variables(when_leafs1)
        then_variables1=extract_variables(then_leafs1)

        # print("Variables Given 1: ", given_variables1)
        # print("Variables When 1: ", when_variables1)
        # print("Variables Then 1: ", then_variables1)

        # print("---")
        scenario_name = next(iter(shared_scenario))

        # print("Shared Scenario: ", scenario_name)

        given_dnf2=to_dnf_expression(get_Given(shared_scenario))
        when_dnf2=to_dnf_expression(get_When(shared_scenario))
        do2=to_dnf_expression(get_Do(shared_scenario))
        then_dnf2=to_dnf_expression(get_Then(shared_scenario))

        # print("Shared Given DNF: ", given_dnf2)
        # print("Shared When DNF: ", when_dnf2)
        # print("Shared Do: ", do2)
        # print("Shared Then DNF: ", then_dnf2)
        # print("")

        given_leafs2=get_leafs(given_dnf2)
        when_leafs2=get_leafs(when_dnf2)
        then_leafs2=get_leafs(then_dnf2)

        # print("Leafs Given 2: ", given_leafs2)
        # print("Leafs When 2: ", when_leafs2)
        # print("Leafs Then 2: ", then_leafs2)
        # print("")
        given_variables2=extract_variables(given_leafs2)
        when_variables2=extract_variables(when_leafs2)
        then_variables2=extract_variables(then_leafs2)

        # print("Variables Given 2: ", given_variables2)
        # print("Variables When 2: ", when_variables2)
        # print("Variables Then 2: ", then_variables2)
        # print("")

        penality_given=penality(given_variables1, given_variables2, alpha=0.9, beta=0.1)
        penality_when=penality(when_variables1, when_variables2, alpha=0.9, beta=0.1)
        penality_then=penality(then_variables1, then_variables2, alpha=0.9, beta=0.1)

        # print("Penality Given: ", penality_given)
        # print("Penality When: ", penality_when)
        # print("Penality Then: ", penality_then)
        # print("")

        pair_leaves_given=pair_leaves(given_leafs1, given_leafs2)
        pair_leaves_when=pair_leaves(when_leafs1, when_leafs2)
        pair_leaves_then=pair_leaves(then_leafs1, then_leafs2)

        # print("Pair Leaves Given: ", pair_leaves_given)
        # print("Pair Leaves When: ", pair_leaves_when)
        # print("Pair Leaves Then: ", pair_leaves_then)
        # print("")

        given_local_similarity_result={}
        when_local_similarity_result={}
        then_local_similarity_result={}

        for pair in pair_leaves_given:
            given_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())

        for pair in pair_leaves_when:
            when_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())

        for pair in pair_leaves_then:
            then_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())


        # print("Given Local Similarity Result: ", given_local_similarity_result)
        # print("When Local Similarity Result: ", when_local_similarity_result)
        # print("Then Local Similarity Result: ", then_local_similarity_result)
        # print("")

        global_similarity_given=similarity_global(given_local_similarity_result)
        global_similarity_when=similarity_global(when_local_similarity_result)
        global_similarity_then=similarity_global(then_local_similarity_result)

        # print("Global Similarity Given: ", global_similarity_given)
        # print("Global Similarity When: ", global_similarity_when)
        # print("Global Similarity Then: ", global_similarity_then)
        # print("")
        
        final_similarity_given=global_similarity_given-penality_given
        final_similarity_when=global_similarity_when-penality_when
        final_similarity_then=global_similarity_then-penality_then

        # print("Final Similarity Given: ", final_similarity_given)
        # print("Final Similarity When: ", final_similarity_when)
        # print("Final Similarity Then: ", final_similarity_then)
        # print("")

        scenario_similarity_result=scenario_similarity(final_similarity_given,
                                                        final_similarity_when,
                                                        final_similarity_then,
                                                        weight_given=1.0,
                                                        weight_when=1.0,
                                                        weight_then=1.0)

        # print("Scenario Similarity: ", scenario_similarity_result)
        # print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")

        # Adiciona os resultados ao DataFrame
        results_to_df.append({
                "Scenario": scenario_name,
                "Desired Given DNF": given_dnf1,
                "Shared Given DNF": given_dnf2,
                # "Desired Given Variables": given_variables1,
                # "Shared Given Variables": given_variables2,
                "Penality Given": penality_given,
                "Global Similarity Given": global_similarity_given,
                "Final Similarity Given": final_similarity_given,
                "Desired When DNF": when_dnf1,
                "Shared When DNF": when_dnf2,
                # "Desired When Variables": when_variables1,
                # "Shared When Variables": when_variables2,
                "Penality When": penality_when,
                "Global Similarity When": global_similarity_when,
                "Final Similarity When": final_similarity_when,
                "Desired Then DNF": then_dnf1,
                "Shared Then DNF": then_dnf2,
                # "Desired Then Variables": then_variables1,
                # "Shared Then Variables": then_variables2,
                "Penality Then": penality_then,
                "Global Similarity Then": global_similarity_then,
                "Final Similarity Then": final_similarity_then,
                "Scenario Similarity": scenario_similarity_result,
                "Action": do2
            })
        

    # Cria o DataFrame
    df_results = pd.DataFrame(results_to_df).sort_values(by="Scenario Similarity", ascending=False)
    df_results = df_results.reset_index(drop=True)

    return df_results

# %%
desired_scenarios=get_desired_scenario()

# %%
desired_scenarios
# Out:
# [{'desired_1': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_1',
#    'Then': 'height >= 30'}},
#  {'desired_2': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_2',
#    'Then': 'height >= 0'}},
#  {'desired_3': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_3',
#    'Then': 'height >= 50'}},
#  {'desired_4': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_4',
#    'Then': 'height <= 30'}},
#  {'desired_5': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_5',
#    'Then': 'height <= 50'}},
#  {'desired_6': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_6',
#    'Then': 'height <= 100'}},
#  {'desired_7': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_7',
#    'Then': 'source_distance == 0'}},
#  {'desired_8': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_8',
#    'Then': 'source_distance >= 0'}},
#  {'desired_9': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_9',
#    'Then': 'source_distance >= 50'}},
#  {'desired_10': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_10',
#    'Then': 'source_distance <= 50'}},
#  {'desired_11': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_11',
#    'Then': 'source_distance <= 100'}},
#  {'desired_12': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_12',
#    'Then': 'a > 10'}},
#  {'desired_13': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_13',
#    'Then': 'b > 10'}},
#  {'desired_14': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_14',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'desired_15': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_15',
#    'Then': 'height >= 30 AND source_distance >= 0'}},
#  {'desired_16': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_16',
#    'Then': 'height >= 30 AND source_distance >= 50'}},
#  {'desired_17': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_17',
#    'Then': 'height >= 30 AND source_distance <= 50'}},
#  {'desired_18': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_18',
#    'Then': 'height >= 30 AND source_distance <= 100'}},
#  {'desired_19': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_19',
#    'Then': 'height >= 0 AND source_distance == 0'}},
#  {'desired_20': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_20',
#    'Then': 'height >= 0 AND source_distance >= 0'}},
#  {'desired_21': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_21',
#    'Then': 'height >= 0 AND source_distance >= 50'}},
#  {'desired_22': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_22',
#    'Then': 'height >= 0 AND source_distance <= 50'}},
#  {'desired_23': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_23',
#    'Then': 'height >= 0 AND source_distance <= 100'}},
#  {'desired_24': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_24',
#    'Then': 'height >= 50 AND source_distance == 0'}},
#  {'desired_25': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_25',
#    'Then': 'height >= 50 AND source_distance >= 0'}},
#  {'desired_26': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_26',
#    'Then': 'height >= 50 AND source_distance >= 50'}},
#  {'desired_27': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_27',
#    'Then': 'height >= 50 AND source_distance <= 50'}},
#  {'desired_28': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_28',
#    'Then': 'height >= 50 AND source_distance <= 100'}},
#  {'desired_29': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_29',
#    'Then': 'height <= 30 AND source_distance == 0'}},
#  {'desired_30': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_30',
#    'Then': 'height <= 30 AND source_distance >= 0'}},
#  {'desired_31': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_31',
#    'Then': 'height <= 30 AND source_distance >= 50'}},
#  {'desired_32': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_32',
#    'Then': 'height <= 30 AND source_distance <= 50'}},
#  {'desired_33': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_33',
#    'Then': 'height <= 30 AND source_distance <= 100'}},
#  {'desired_34': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_34',
#    'Then': 'height <= 50 AND source_distance == 0'}},
#  {'desired_35': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_35',
#    'Then': 'height <= 50 AND source_distance >= 0'}},
#  {'desired_36': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_36',
#    'Then': 'height <= 50 AND source_distance >= 50'}},
#  {'desired_37': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_37',
#    'Then': 'height <= 50 AND source_distance <= 50'}},
#  {'desired_38': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_38',
#    'Then': 'height <= 50 AND source_distance <= 100'}},
#  {'desired_39': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_39',
#    'Then': 'height <= 100 AND source_distance == 0'}},
#  {'desired_40': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_40',
#    'Then': 'height <= 100 AND source_distance >= 0'}},
#  {'desired_41': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_41',
#    'Then': 'height <= 100 AND source_distance >= 50'}},
#  {'desired_42': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_42',
#    'Then': 'height <= 100 AND source_distance <= 50'}},
#  {'desired_43': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_43',
#    'Then': 'height <= 100 AND source_distance <= 100'}},
#  {'desired_44': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_44',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'desired_45': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_45',
#    'Then': 'height >= 0 AND a > 10'}},
#  {'desired_46': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_46',
#    'Then': 'height >= 50 AND a > 10'}},
#  {'desired_47': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_47',
#    'Then': 'height <= 30 AND a > 10'}},
#  {'desired_48': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_48',
#    'Then': 'height <= 50 AND a > 10'}},
#  {'desired_49': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_49',
#    'Then': 'height <= 100 AND a > 10'}},
#  {'desired_50': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_50',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'desired_51': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_51',
#    'Then': 'height >= 0 AND b > 10'}},
#  {'desired_52': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_52',
#    'Then': 'height >= 50 AND b > 10'}},
#  {'desired_53': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_53',
#    'Then': 'height <= 30 AND b > 10'}},
#  {'desired_54': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_54',
#    'Then': 'height <= 50 AND b > 10'}},
#  {'desired_55': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_55',
#    'Then': 'height <= 100 AND b > 10'}},
#  {'desired_56': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_56',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'desired_57': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_57',
#    'Then': 'source_distance >= 0 AND a > 10'}},
#  {'desired_58': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_58',
#    'Then': 'source_distance >= 50 AND a > 10'}},
#  {'desired_59': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_59',
#    'Then': 'source_distance <= 50 AND a > 10'}},
#  {'desired_60': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_60',
#    'Then': 'source_distance <= 100 AND a > 10'}},
#  {'desired_61': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_61',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'desired_62': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_62',
#    'Then': 'source_distance >= 0 AND b > 10'}},
#  {'desired_63': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_63',
#    'Then': 'source_distance >= 50 AND b > 10'}},
#  {'desired_64': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_64',
#    'Then': 'source_distance <= 50 AND b > 10'}},
#  {'desired_65': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_65',
#    'Then': 'source_distance <= 100 AND b > 10'}},
#  {'desired_66': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_66',
#    'Then': 'a > 10 AND b > 10'}},
#  {'desired_67': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_67',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'desired_68': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_68',
#    'Then': 'height >= 30 AND source_distance >= 0 AND a > 10'}},
#  {'desired_69': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_69',
#    'Then': 'height >= 30 AND source_distance >= 50 AND a > 10'}},
#  {'desired_70': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_70',
#    'Then': 'height >= 30 AND source_distance <= 50 AND a > 10'}},
#  {'desired_71': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_71',
#    'Then': 'height >= 30 AND source_distance <= 100 AND a > 10'}},
#  {'desired_72': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_72',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10'}},
#  {'desired_73': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_73',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10'}},
#  {'desired_74': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_74',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10'}},
#  {'desired_75': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_75',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10'}},
#  {'desired_76': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_76',
#    'Then': 'height >= 0 AND source_distance <= 100 AND a > 10'}},
#  {'desired_77': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_77',
#    'Then': 'height >= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_78': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_78',
#    'Then': 'height >= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_79': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_79',
#    'Then': 'height >= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_80': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_80',
#    'Then': 'height >= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_81': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_81',
#    'Then': 'height >= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_82': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_82',
#    'Then': 'height <= 30 AND source_distance == 0 AND a > 10'}},
#  {'desired_83': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_83',
#    'Then': 'height <= 30 AND source_distance >= 0 AND a > 10'}},
#  {'desired_84': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_84',
#    'Then': 'height <= 30 AND source_distance >= 50 AND a > 10'}},
#  {'desired_85': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_85',
#    'Then': 'height <= 30 AND source_distance <= 50 AND a > 10'}},
#  {'desired_86': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_86',
#    'Then': 'height <= 30 AND source_distance <= 100 AND a > 10'}},
#  {'desired_87': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_87',
#    'Then': 'height <= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_88': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_88',
#    'Then': 'height <= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_89': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_89',
#    'Then': 'height <= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_90': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_90',
#    'Then': 'height <= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_91': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_91',
#    'Then': 'height <= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_92': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_92',
#    'Then': 'height <= 100 AND source_distance == 0 AND a > 10'}},
#  {'desired_93': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_93',
#    'Then': 'height <= 100 AND source_distance >= 0 AND a > 10'}},
#  {'desired_94': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_94',
#    'Then': 'height <= 100 AND source_distance >= 50 AND a > 10'}},
#  {'desired_95': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_95',
#    'Then': 'height <= 100 AND source_distance <= 50 AND a > 10'}},
#  {'desired_96': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_96',
#    'Then': 'height <= 100 AND source_distance <= 100 AND a > 10'}},
#  {'desired_97': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_97',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_98': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_98',
#    'Then': 'height >= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_99': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_99',
#    'Then': 'height >= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_100': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_100',
#    'Then': 'height >= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_101': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_101',
#    'Then': 'height >= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_102': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_102',
#    'Then': 'height >= 0 AND source_distance == 0 AND b > 10'}},
#  {'desired_103': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_103',
#    'Then': 'height >= 0 AND source_distance >= 0 AND b > 10'}},
#  {'desired_104': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_104',
#    'Then': 'height >= 0 AND source_distance >= 50 AND b > 10'}},
#  {'desired_105': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_105',
#    'Then': 'height >= 0 AND source_distance <= 50 AND b > 10'}},
#  {'desired_106': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_106',
#    'Then': 'height >= 0 AND source_distance <= 100 AND b > 10'}},
#  {'desired_107': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_107',
#    'Then': 'height >= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_108': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_108',
#    'Then': 'height >= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_109': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_109',
#    'Then': 'height >= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_110': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_110',
#    'Then': 'height >= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_111': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_111',
#    'Then': 'height >= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_112': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_112',
#    'Then': 'height <= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_113': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_113',
#    'Then': 'height <= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_114': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_114',
#    'Then': 'height <= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_115': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_115',
#    'Then': 'height <= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_116': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_116',
#    'Then': 'height <= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_117': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_117',
#    'Then': 'height <= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_118': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_118',
#    'Then': 'height <= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_119': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_119',
#    'Then': 'height <= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_120': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_120',
#    'Then': 'height <= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_121': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_121',
#    'Then': 'height <= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_122': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_122',
#    'Then': 'height <= 100 AND source_distance == 0 AND b > 10'}},
#  {'desired_123': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_123',
#    'Then': 'height <= 100 AND source_distance >= 0 AND b > 10'}},
#  {'desired_124': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_124',
#    'Then': 'height <= 100 AND source_distance >= 50 AND b > 10'}},
#  {'desired_125': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_125',
#    'Then': 'height <= 100 AND source_distance <= 50 AND b > 10'}},
#  {'desired_126': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_126',
#    'Then': 'height <= 100 AND source_distance <= 100 AND b > 10'}},
#  {'desired_127': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_127',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'desired_128': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_128',
#    'Then': 'height >= 0 AND a > 10 AND b > 10'}},
#  {'desired_129': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_129',
#    'Then': 'height >= 50 AND a > 10 AND b > 10'}},
#  {'desired_130': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_130',
#    'Then': 'height <= 30 AND a > 10 AND b > 10'}},
#  {'desired_131': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_131',
#    'Then': 'height <= 50 AND a > 10 AND b > 10'}},
#  {'desired_132': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_132',
#    'Then': 'height <= 100 AND a > 10 AND b > 10'}},
#  {'desired_133': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_133',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_134': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_134',
#    'Then': 'source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_135': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_135',
#    'Then': 'source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_136': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_136',
#    'Then': 'source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_137': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_137',
#    'Then': 'source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_138': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_138',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_139': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_139',
#    'Then': 'height >= 30 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_140': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_140',
#    'Then': 'height >= 30 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_141': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_141',
#    'Then': 'height >= 30 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_142': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_142',
#    'Then': 'height >= 30 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_143': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_143',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_144': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_144',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_145': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_145',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_146': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_146',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_147': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_147',
#    'Then': 'height >= 0 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_148': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_148',
#    'Then': 'height >= 50 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_149': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_149',
#    'Then': 'height >= 50 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_150': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_150',
#    'Then': 'height >= 50 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_151': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_151',
#    'Then': 'height >= 50 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_152': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_152',
#    'Then': 'height >= 50 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_153': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_153',
#    'Then': 'height <= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_154': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_154',
#    'Then': 'height <= 30 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_155': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_155',
#    'Then': 'height <= 30 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_156': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_156',
#    'Then': 'height <= 30 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_157': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_157',
#    'Then': 'height <= 30 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_158': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_158',
#    'Then': 'height <= 50 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_159': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_159',
#    'Then': 'height <= 50 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_160': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_160',
#    'Then': 'height <= 50 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_161': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_161',
#    'Then': 'height <= 50 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_162': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_162',
#    'Then': 'height <= 50 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_163': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_163',
#    'Then': 'height <= 100 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_164': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_164',
#    'Then': 'height <= 100 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_165': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_165',
#    'Then': 'height <= 100 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_166': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_166',
#    'Then': 'height <= 100 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_167': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_167',
#    'Then': 'height <= 100 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_168': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_168',
#    'Then': 'height >= 30'}},
#  {'desired_169': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_169',
#    'Then': 'height >= 0'}},
#  {'desired_170': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_170',
#    'Then': 'height >= 50'}},
#  {'desired_171': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_171',
#    'Then': 'height <= 30'}},
#  {'desired_172': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_172',
#    'Then': 'height <= 50'}},
#  {'desired_173': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_173',
#    'Then': 'height <= 100'}},
#  {'desired_174': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_174',
#    'Then': 'source_distance == 0'}},
#  {'desired_175': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_175',
#    'Then': 'source_distance >= 0'}},
#  {'desired_176': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_176',
#    'Then': 'source_distance >= 50'}},
#  {'desired_177': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_177',
#    'Then': 'source_distance <= 50'}},
#  {'desired_178': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_178',
#    'Then': 'source_distance <= 100'}},
#  {'desired_179': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_179',
#    'Then': 'a > 10'}},
#  {'desired_180': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_180',
#    'Then': 'b > 10'}},
#  {'desired_181': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_181',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'desired_182': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_182',
#    'Then': 'height >= 30 AND source_distance >= 0'}},
#  {'desired_183': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_183',
#    'Then': 'height >= 30 AND source_distance >= 50'}},
#  {'desired_184': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_184',
#    'Then': 'height >= 30 AND source_distance <= 50'}},
#  {'desired_185': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_185',
#    'Then': 'height >= 30 AND source_distance <= 100'}},
#  {'desired_186': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_186',
#    'Then': 'height >= 0 AND source_distance == 0'}},
#  {'desired_187': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_187',
#    'Then': 'height >= 0 AND source_distance >= 0'}},
#  {'desired_188': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_188',
#    'Then': 'height >= 0 AND source_distance >= 50'}},
#  {'desired_189': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_189',
#    'Then': 'height >= 0 AND source_distance <= 50'}},
#  {'desired_190': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_190',
#    'Then': 'height >= 0 AND source_distance <= 100'}},
#  {'desired_191': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_191',
#    'Then': 'height >= 50 AND source_distance == 0'}},
#  {'desired_192': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_192',
#    'Then': 'height >= 50 AND source_distance >= 0'}},
#  {'desired_193': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_193',
#    'Then': 'height >= 50 AND source_distance >= 50'}},
#  {'desired_194': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_194',
#    'Then': 'height >= 50 AND source_distance <= 50'}},
#  {'desired_195': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_195',
#    'Then': 'height >= 50 AND source_distance <= 100'}},
#  {'desired_196': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_196',
#    'Then': 'height <= 30 AND source_distance == 0'}},
#  {'desired_197': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_197',
#    'Then': 'height <= 30 AND source_distance >= 0'}},
#  {'desired_198': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_198',
#    'Then': 'height <= 30 AND source_distance >= 50'}},
#  {'desired_199': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_199',
#    'Then': 'height <= 30 AND source_distance <= 50'}},
#  {'desired_200': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_200',
#    'Then': 'height <= 30 AND source_distance <= 100'}},
#  {'desired_201': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_201',
#    'Then': 'height <= 50 AND source_distance == 0'}},
#  {'desired_202': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_202',
#    'Then': 'height <= 50 AND source_distance >= 0'}},
#  {'desired_203': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_203',
#    'Then': 'height <= 50 AND source_distance >= 50'}},
#  {'desired_204': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_204',
#    'Then': 'height <= 50 AND source_distance <= 50'}},
#  {'desired_205': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_205',
#    'Then': 'height <= 50 AND source_distance <= 100'}},
#  {'desired_206': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_206',
#    'Then': 'height <= 100 AND source_distance == 0'}},
#  {'desired_207': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_207',
#    'Then': 'height <= 100 AND source_distance >= 0'}},
#  {'desired_208': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_208',
#    'Then': 'height <= 100 AND source_distance >= 50'}},
#  {'desired_209': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_209',
#    'Then': 'height <= 100 AND source_distance <= 50'}},
#  {'desired_210': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_210',
#    'Then': 'height <= 100 AND source_distance <= 100'}},
#  {'desired_211': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_211',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'desired_212': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_212',
#    'Then': 'height >= 0 AND a > 10'}},
#  {'desired_213': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_213',
#    'Then': 'height >= 50 AND a > 10'}},
#  {'desired_214': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_214',
#    'Then': 'height <= 30 AND a > 10'}},
#  {'desired_215': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_215',
#    'Then': 'height <= 50 AND a > 10'}},
#  {'desired_216': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_216',
#    'Then': 'height <= 100 AND a > 10'}},
#  {'desired_217': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_217',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'desired_218': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_218',
#    'Then': 'height >= 0 AND b > 10'}},
#  {'desired_219': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_219',
#    'Then': 'height >= 50 AND b > 10'}},
#  {'desired_220': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_220',
#    'Then': 'height <= 30 AND b > 10'}},
#  {'desired_221': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_221',
#    'Then': 'height <= 50 AND b > 10'}},
#  {'desired_222': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_222',
#    'Then': 'height <= 100 AND b > 10'}},
#  {'desired_223': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_223',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'desired_224': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_224',
#    'Then': 'source_distance >= 0 AND a > 10'}},
#  {'desired_225': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_225',
#    'Then': 'source_distance >= 50 AND a > 10'}},
#  {'desired_226': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_226',
#    'Then': 'source_distance <= 50 AND a > 10'}},
#  {'desired_227': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_227',
#    'Then': 'source_distance <= 100 AND a > 10'}},
#  {'desired_228': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_228',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'desired_229': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_229',
#    'Then': 'source_distance >= 0 AND b > 10'}},
#  {'desired_230': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_230',
#    'Then': 'source_distance >= 50 AND b > 10'}},
#  {'desired_231': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_231',
#    'Then': 'source_distance <= 50 AND b > 10'}},
#  {'desired_232': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_232',
#    'Then': 'source_distance <= 100 AND b > 10'}},
#  {'desired_233': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_233',
#    'Then': 'a > 10 AND b > 10'}},
#  {'desired_234': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_234',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'desired_235': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_235',
#    'Then': 'height >= 30 AND source_distance >= 0 AND a > 10'}},
#  {'desired_236': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_236',
#    'Then': 'height >= 30 AND source_distance >= 50 AND a > 10'}},
#  {'desired_237': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_237',
#    'Then': 'height >= 30 AND source_distance <= 50 AND a > 10'}},
#  {'desired_238': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_238',
#    'Then': 'height >= 30 AND source_distance <= 100 AND a > 10'}},
#  {'desired_239': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_239',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10'}},
#  {'desired_240': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_240',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10'}},
#  {'desired_241': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_241',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10'}},
#  {'desired_242': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_242',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10'}},
#  {'desired_243': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_243',
#    'Then': 'height >= 0 AND source_distance <= 100 AND a > 10'}},
#  {'desired_244': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_244',
#    'Then': 'height >= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_245': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_245',
#    'Then': 'height >= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_246': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_246',
#    'Then': 'height >= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_247': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_247',
#    'Then': 'height >= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_248': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_248',
#    'Then': 'height >= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_249': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_249',
#    'Then': 'height <= 30 AND source_distance == 0 AND a > 10'}},
#  {'desired_250': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_250',
#    'Then': 'height <= 30 AND source_distance >= 0 AND a > 10'}},
#  {'desired_251': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_251',
#    'Then': 'height <= 30 AND source_distance >= 50 AND a > 10'}},
#  {'desired_252': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_252',
#    'Then': 'height <= 30 AND source_distance <= 50 AND a > 10'}},
#  {'desired_253': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_253',
#    'Then': 'height <= 30 AND source_distance <= 100 AND a > 10'}},
#  {'desired_254': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_254',
#    'Then': 'height <= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_255': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_255',
#    'Then': 'height <= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_256': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_256',
#    'Then': 'height <= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_257': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_257',
#    'Then': 'height <= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_258': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_258',
#    'Then': 'height <= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_259': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_259',
#    'Then': 'height <= 100 AND source_distance == 0 AND a > 10'}},
#  {'desired_260': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_260',
#    'Then': 'height <= 100 AND source_distance >= 0 AND a > 10'}},
#  {'desired_261': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_261',
#    'Then': 'height <= 100 AND source_distance >= 50 AND a > 10'}},
#  {'desired_262': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_262',
#    'Then': 'height <= 100 AND source_distance <= 50 AND a > 10'}},
#  {'desired_263': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_263',
#    'Then': 'height <= 100 AND source_distance <= 100 AND a > 10'}},
#  {'desired_264': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_264',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_265': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_265',
#    'Then': 'height >= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_266': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_266',
#    'Then': 'height >= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_267': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_267',
#    'Then': 'height >= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_268': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_268',
#    'Then': 'height >= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_269': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_269',
#    'Then': 'height >= 0 AND source_distance == 0 AND b > 10'}},
#  {'desired_270': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_270',
#    'Then': 'height >= 0 AND source_distance >= 0 AND b > 10'}},
#  {'desired_271': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_271',
#    'Then': 'height >= 0 AND source_distance >= 50 AND b > 10'}},
#  {'desired_272': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_272',
#    'Then': 'height >= 0 AND source_distance <= 50 AND b > 10'}},
#  {'desired_273': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_273',
#    'Then': 'height >= 0 AND source_distance <= 100 AND b > 10'}},
#  {'desired_274': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_274',
#    'Then': 'height >= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_275': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_275',
#    'Then': 'height >= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_276': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_276',
#    'Then': 'height >= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_277': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_277',
#    'Then': 'height >= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_278': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_278',
#    'Then': 'height >= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_279': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_279',
#    'Then': 'height <= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_280': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_280',
#    'Then': 'height <= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_281': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_281',
#    'Then': 'height <= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_282': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_282',
#    'Then': 'height <= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_283': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_283',
#    'Then': 'height <= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_284': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_284',
#    'Then': 'height <= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_285': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_285',
#    'Then': 'height <= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_286': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_286',
#    'Then': 'height <= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_287': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_287',
#    'Then': 'height <= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_288': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_288',
#    'Then': 'height <= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_289': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_289',
#    'Then': 'height <= 100 AND source_distance == 0 AND b > 10'}},
#  {'desired_290': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_290',
#    'Then': 'height <= 100 AND source_distance >= 0 AND b > 10'}},
#  {'desired_291': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_291',
#    'Then': 'height <= 100 AND source_distance >= 50 AND b > 10'}},
#  {'desired_292': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_292',
#    'Then': 'height <= 100 AND source_distance <= 50 AND b > 10'}},
#  {'desired_293': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_293',
#    'Then': 'height <= 100 AND source_distance <= 100 AND b > 10'}},
#  {'desired_294': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_294',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'desired_295': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_295',
#    'Then': 'height >= 0 AND a > 10 AND b > 10'}},
#  {'desired_296': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_296',
#    'Then': 'height >= 50 AND a > 10 AND b > 10'}},
#  {'desired_297': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_297',
#    'Then': 'height <= 30 AND a > 10 AND b > 10'}},
#  {'desired_298': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_298',
#    'Then': 'height <= 50 AND a > 10 AND b > 10'}},
#  {'desired_299': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_299',
#    'Then': 'height <= 100 AND a > 10 AND b > 10'}},
#  {'desired_300': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_300',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_301': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_301',
#    'Then': 'source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_302': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_302',
#    'Then': 'source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_303': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_303',
#    'Then': 'source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_304': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_304',
#    'Then': 'source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_305': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_305',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_306': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_306',
#    'Then': 'height >= 30 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_307': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_307',
#    'Then': 'height >= 30 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_308': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_308',
#    'Then': 'height >= 30 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_309': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_309',
#    'Then': 'height >= 30 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_310': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_310',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_311': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_311',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_312': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_312',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_313': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_313',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_314': {'Given': 'battery >= 0',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_314',
# ...
#    'Do': 'behavior_907',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10'}},
#  {'desired_908': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_908',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10'}},
#  {'desired_909': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_909',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10'}},
#  {'desired_910': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_910',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10'}},
#  {'desired_911': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_911',
#    'Then': 'height >= 0 AND source_distance <= 100 AND a > 10'}},
#  {'desired_912': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_912',
#    'Then': 'height >= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_913': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_913',
#    'Then': 'height >= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_914': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_914',
#    'Then': 'height >= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_915': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_915',
#    'Then': 'height >= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_916': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_916',
#    'Then': 'height >= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_917': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_917',
#    'Then': 'height <= 30 AND source_distance == 0 AND a > 10'}},
#  {'desired_918': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_918',
#    'Then': 'height <= 30 AND source_distance >= 0 AND a > 10'}},
#  {'desired_919': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_919',
#    'Then': 'height <= 30 AND source_distance >= 50 AND a > 10'}},
#  {'desired_920': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_920',
#    'Then': 'height <= 30 AND source_distance <= 50 AND a > 10'}},
#  {'desired_921': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_921',
#    'Then': 'height <= 30 AND source_distance <= 100 AND a > 10'}},
#  {'desired_922': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_922',
#    'Then': 'height <= 50 AND source_distance == 0 AND a > 10'}},
#  {'desired_923': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_923',
#    'Then': 'height <= 50 AND source_distance >= 0 AND a > 10'}},
#  {'desired_924': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_924',
#    'Then': 'height <= 50 AND source_distance >= 50 AND a > 10'}},
#  {'desired_925': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_925',
#    'Then': 'height <= 50 AND source_distance <= 50 AND a > 10'}},
#  {'desired_926': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_926',
#    'Then': 'height <= 50 AND source_distance <= 100 AND a > 10'}},
#  {'desired_927': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_927',
#    'Then': 'height <= 100 AND source_distance == 0 AND a > 10'}},
#  {'desired_928': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_928',
#    'Then': 'height <= 100 AND source_distance >= 0 AND a > 10'}},
#  {'desired_929': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_929',
#    'Then': 'height <= 100 AND source_distance >= 50 AND a > 10'}},
#  {'desired_930': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_930',
#    'Then': 'height <= 100 AND source_distance <= 50 AND a > 10'}},
#  {'desired_931': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_931',
#    'Then': 'height <= 100 AND source_distance <= 100 AND a > 10'}},
#  {'desired_932': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_932',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_933': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_933',
#    'Then': 'height >= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_934': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_934',
#    'Then': 'height >= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_935': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_935',
#    'Then': 'height >= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_936': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_936',
#    'Then': 'height >= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_937': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_937',
#    'Then': 'height >= 0 AND source_distance == 0 AND b > 10'}},
#  {'desired_938': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_938',
#    'Then': 'height >= 0 AND source_distance >= 0 AND b > 10'}},
#  {'desired_939': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_939',
#    'Then': 'height >= 0 AND source_distance >= 50 AND b > 10'}},
#  {'desired_940': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_940',
#    'Then': 'height >= 0 AND source_distance <= 50 AND b > 10'}},
#  {'desired_941': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_941',
#    'Then': 'height >= 0 AND source_distance <= 100 AND b > 10'}},
#  {'desired_942': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_942',
#    'Then': 'height >= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_943': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_943',
#    'Then': 'height >= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_944': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_944',
#    'Then': 'height >= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_945': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_945',
#    'Then': 'height >= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_946': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_946',
#    'Then': 'height >= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_947': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_947',
#    'Then': 'height <= 30 AND source_distance == 0 AND b > 10'}},
#  {'desired_948': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_948',
#    'Then': 'height <= 30 AND source_distance >= 0 AND b > 10'}},
#  {'desired_949': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_949',
#    'Then': 'height <= 30 AND source_distance >= 50 AND b > 10'}},
#  {'desired_950': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_950',
#    'Then': 'height <= 30 AND source_distance <= 50 AND b > 10'}},
#  {'desired_951': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_951',
#    'Then': 'height <= 30 AND source_distance <= 100 AND b > 10'}},
#  {'desired_952': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_952',
#    'Then': 'height <= 50 AND source_distance == 0 AND b > 10'}},
#  {'desired_953': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_953',
#    'Then': 'height <= 50 AND source_distance >= 0 AND b > 10'}},
#  {'desired_954': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_954',
#    'Then': 'height <= 50 AND source_distance >= 50 AND b > 10'}},
#  {'desired_955': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_955',
#    'Then': 'height <= 50 AND source_distance <= 50 AND b > 10'}},
#  {'desired_956': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_956',
#    'Then': 'height <= 50 AND source_distance <= 100 AND b > 10'}},
#  {'desired_957': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_957',
#    'Then': 'height <= 100 AND source_distance == 0 AND b > 10'}},
#  {'desired_958': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_958',
#    'Then': 'height <= 100 AND source_distance >= 0 AND b > 10'}},
#  {'desired_959': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_959',
#    'Then': 'height <= 100 AND source_distance >= 50 AND b > 10'}},
#  {'desired_960': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_960',
#    'Then': 'height <= 100 AND source_distance <= 50 AND b > 10'}},
#  {'desired_961': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_961',
#    'Then': 'height <= 100 AND source_distance <= 100 AND b > 10'}},
#  {'desired_962': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_962',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'desired_963': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_963',
#    'Then': 'height >= 0 AND a > 10 AND b > 10'}},
#  {'desired_964': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_964',
#    'Then': 'height >= 50 AND a > 10 AND b > 10'}},
#  {'desired_965': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_965',
#    'Then': 'height <= 30 AND a > 10 AND b > 10'}},
#  {'desired_966': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_966',
#    'Then': 'height <= 50 AND a > 10 AND b > 10'}},
#  {'desired_967': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_967',
#    'Then': 'height <= 100 AND a > 10 AND b > 10'}},
#  {'desired_968': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_968',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_969': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_969',
#    'Then': 'source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_970': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_970',
#    'Then': 'source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_971': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_971',
#    'Then': 'source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_972': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_972',
#    'Then': 'source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_973': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_973',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_974': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_974',
#    'Then': 'height >= 30 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_975': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_975',
#    'Then': 'height >= 30 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_976': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_976',
#    'Then': 'height >= 30 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_977': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_977',
#    'Then': 'height >= 30 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_978': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_978',
#    'Then': 'height >= 0 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_979': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_979',
#    'Then': 'height >= 0 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_980': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_980',
#    'Then': 'height >= 0 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_981': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_981',
#    'Then': 'height >= 0 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_982': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_982',
#    'Then': 'height >= 0 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_983': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_983',
#    'Then': 'height >= 50 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_984': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_984',
#    'Then': 'height >= 50 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_985': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_985',
#    'Then': 'height >= 50 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_986': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_986',
#    'Then': 'height >= 50 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_987': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_987',
#    'Then': 'height >= 50 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_988': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_988',
#    'Then': 'height <= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_989': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_989',
#    'Then': 'height <= 30 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_990': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_990',
#    'Then': 'height <= 30 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_991': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_991',
#    'Then': 'height <= 30 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_992': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_992',
#    'Then': 'height <= 30 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_993': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_993',
#    'Then': 'height <= 50 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_994': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_994',
#    'Then': 'height <= 50 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_995': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_995',
#    'Then': 'height <= 50 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  {'desired_996': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_996',
#    'Then': 'height <= 50 AND source_distance <= 50 AND a > 10 AND b > 10'}},
#  {'desired_997': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_997',
#    'Then': 'height <= 50 AND source_distance <= 100 AND a > 10 AND b > 10'}},
#  {'desired_998': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_998',
#    'Then': 'height <= 100 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'desired_999': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_999',
#    'Then': 'height <= 100 AND source_distance >= 0 AND a > 10 AND b > 10'}},
#  {'desired_1000': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_1000',
#    'Then': 'height <= 100 AND source_distance >= 50 AND a > 10 AND b > 10'}},
#  ...]

# %%
desired_scenarios=get_desired_scenario()
results_for_scenario = []

for current_desired_scenario in desired_scenarios:
    desired_scenario_name = next(iter(current_desired_scenario))

    df_result=similarity(current_desired_scenario)
    results_for_scenario.append({desired_scenario_name:df_result})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 7
#       4 for current_desired_scenario in desired_scenarios:
#       5     desired_scenario_name = next(iter(current_desired_scenario))
# ----> 7     df_result=similarity(current_desired_scenario)
#       8     results_for_scenario.append({desired_scenario_name:df_result})
#
# Cell In[39], line 42, in similarity(desired_scenario)
#      40 given_dnf2=to_dnf_expression(get_Given(shared_scenario))
#      41 when_dnf2=to_dnf_expression(get_When(shared_scenario))
# ---> 42 do2=to_dnf_expression(get_Do(shared_scenario))
#      43 then_dnf2=to_dnf_expression(get_Then(shared_scenario))
#      45 # print("Shared Given DNF: ", given_dnf2)
#      46 # print("Shared When DNF: ", when_dnf2)
#      47 # print("Shared Do: ", do2)
#      48 # print("Shared Then DNF: ", then_dnf2)
#      49 # print("")
#
# Cell In[26], line 3, in to_dnf_expression(expression_scenario)
#       1 def to_dnf_expression(expression_scenario):
# ----> 3     parsed_expression = logical_expression_settings().parseString(expression_scenario, parseAll=True)
#       4     # print("Parsed Expression:", parsed_expression)
#       6     extracted_leaves=extract_leaves(parsed_expression.asList())
#
# Cell In[20], line 16, in logical_expression_settings()
#      13 operand = identifier | number
#      15 # Definir expressão lógica
# ---> 16 logical_expr = infixNotation(operand,
#      17     [
#      18         (comparison_operator, 2, opAssoc.LEFT),
#      19         ("AND", 2, opAssoc.LEFT),
#      20         ("OR", 2, opAssoc.LEFT),
#      21     ])
#      23 return logical_expr
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\site-packages\pyparsing\util.py:265, in replaced_by_pep8.<locals>._inner(*args, **kwargs)
#     260 @wraps(fn)
#     261 def _inner(*args, **kwargs):
#     262     # warnings.warn(
#     263     #     f"Deprecated - use {fn.__name__}", DeprecationWarning, stacklevel=2
#     264     # )
# --> 265     return fn(*args, **kwargs)
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\site-packages\pyparsing\helpers.py:818, in infix_notation(base_expr, op_list, lpar, rpar)
#     815 if rightLeftAssoc not in (OpAssoc.LEFT, OpAssoc.RIGHT):
#     816     raise ValueError("operator must indicate right or left associativity")
# --> 818 thisExpr: ParserElement = Forward().set_name(term_name)
#     819 thisExpr = typing.cast(Forward, thisExpr)
#     820 if rightLeftAssoc is OpAssoc.LEFT:
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\site-packages\pyparsing\core.py:5445, in Forward.__init__(self, other)
#    5444 def __init__(self, other: typing.Optional[Union[ParserElement, str]] = None):
# -> 5445     self.caller_frame = traceback.extract_stack(limit=2)[0]
#    5446     super().__init__(other, savelist=False)  # type: ignore[arg-type]
#    5447     self.lshift_line = None
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\traceback.py:228, in extract_stack(f, limit)
#     226 if f is None:
#     227     f = sys._getframe().f_back
# --> 228 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     229 stack.reverse()
#     230 return stack
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\traceback.py:390, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     387     for f, lineno in frame_gen:
#     388         yield f, (lineno, None, None, None)
# --> 390 return klass._extract_from_extended_frame_gen(
#     391     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     392     capture_locals=capture_locals)
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\traceback.py:429, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     425     result.append(FrameSummary(
#     426         filename, lineno, name, lookup_line=False, locals=f_locals,
#     427         end_lineno=end_lineno, colno=colno, end_colno=end_colno))
#     428 for filename in fnames:
# --> 429     linecache.checkcache(filename)
#     430 # If immediate lookup was desired, trigger lookups now.
#     431 if lookup_lines:
#
# File c:\Users\lucas\anaconda3\envs\USAS\Lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
import time
start = time.time()
# juntar tudo em um dataframe só para ficar mais fácil salvar.
all_similarities_df = pd.DataFrame()

for result in results_for_scenario:
    desired_scenario_name = next(iter(result))

    temp_df = result[desired_scenario_name]
    temp_df.insert(0, "desired_scenario",desired_scenario_name)
    temp_df.rename(columns={'Scenario': 'cadidate_scenario'}, inplace=True)

    all_similarities_df = pd.concat([all_similarities_df, temp_df], ignore_index=True)
end = time.time()
print(end - start)

# %%
all_similarities_df
# Out:
#       desired_scenario cadidate_scenario  \
# 0            desired_1       Candidate_1
# 1            desired_1      Candidate_12
# 2            desired_1      Candidate_21
# 3            desired_1      Candidate_20
# 4            desired_1      Candidate_19
# ...                ...               ...
# 22512       desired_11       Candidate_8
# 22513       desired_11       Candidate_9
# 22514       desired_11      Candidate_10
# 22515       desired_11      Candidate_11
# 22516       desired_11       Candidate_1
#
#                                                                                                                                                                                           Desired Given DNF  \
# 0                                                                                                                                                                                             battery >= 10
# 1                                                                                                                                                                                             battery >= 10
# 2                                                                                                                                                                                             battery >= 10
# 3                                                                                                                                                                                             battery >= 10
# 4                                                                                                                                                                                             battery >= 10
# ...                                                                                                                                                                                                     ...
# 22512  battery >= 10 AND c > 10 AND d > 10 AND e > 10 AND satellite_count >= 7 AND wind_speed <= 36 AND visibility >= 10 AND temperature <= 25 AND vibration <= 50 AND humidity <= 80 AND a > 10 AND b > 10
# 22513  battery >= 10 AND c > 10 AND d > 10 AND e > 10 AND satellite_count >= 7 AND wind_speed <= 36 AND visibility >= 10 AND temperature <= 25 AND vibration <= 50 AND humidity <= 80 AND a > 10 AND b > 10
# 22514  battery >= 10 AND c > 10 AND d > 10 AND e > 10 AND satellite_count >= 7 AND wind_speed <= 36 AND visibility >= 10 AND temperature <= 25 AND vibration <= 50 AND humidity <= 80 AND a > 10 AND b > 10
# 22515  battery >= 10 AND c > 10 AND d > 10 AND e > 10 AND satellite_count >= 7 AND wind_speed <= 36 AND visibility >= 10 AND temperature <= 25 AND vibration <= 50 AND humidity <= 80 AND a > 10 AND b > 10
# 22516  battery >= 10 AND c > 10 AND d > 10 AND e > 10 AND satellite_count >= 7 AND wind_speed <= 36 AND visibility >= 10 AND temperature <= 25 AND vibration <= 50 AND humidity <= 80 AND a > 10 AND b > 10
#
#                              Shared Given DNF  Penality Given  \
# 0                               battery >= 10        0.000000
# 1      battery >= 10 AND satellite_count >= 7        0.090909
# 2                    battery >= 10 AND e > 10        0.090909
# 3                    battery >= 10 AND d > 10        0.090909
# 4                    battery >= 10 AND c > 10        0.090909
# ...                                       ...             ...
# 22512                                  b > 10        0.908257
# 22513                                  c > 10        0.908257
# 22514                                  d > 10        0.908257
# 22515                                  e > 10        0.908257
# 22516                           battery >= 10        0.908257
#
#        Global Similarity Given  Final Similarity Given Desired When DNF  \
# 0                          1.0                1.000000     takeoff == 1
# 1                          1.0                0.909091     takeoff == 1
# 2                          1.0                0.909091     takeoff == 1
# 3                          1.0                0.909091     takeoff == 1
# 4                          1.0                0.909091     takeoff == 1
# ...                        ...                     ...              ...
# 22512                      1.0                0.091743     takeoff == 1
# 22513                      1.0                0.091743     takeoff == 1
# 22514                      1.0                0.091743     takeoff == 1
# 22515                      1.0                0.091743     takeoff == 1
# 22516                      1.0                0.091743     takeoff == 1
#
#       Shared When DNF  Penality When  Global Similarity When  \
# 0        takeoff == 1            0.0                     1.0
# 1        takeoff == 1            0.0                     1.0
# 2        takeoff == 1            0.0                     1.0
# 3        takeoff == 1            0.0                     1.0
# 4        takeoff == 1            0.0                     1.0
# ...               ...            ...                     ...
# 22512    takeoff == 1            0.0                     1.0
# 22513    takeoff == 1            0.0                     1.0
# 22514    takeoff == 1            0.0                     1.0
# 22515    takeoff == 1            0.0                     1.0
# 22516    takeoff == 1            0.0                     1.0
#
#        Final Similarity When                       Desired Then DNF  \
# 0                        1.0  height >= 30 AND source_distance == 0
# 1                        1.0  height >= 30 AND source_distance == 0
# 2                        1.0  height >= 30 AND source_distance == 0
# 3                        1.0  height >= 30 AND source_distance == 0
# 4                        1.0  height >= 30 AND source_distance == 0
# ...                      ...                                    ...
# 22512                    1.0  height >= 30 AND source_distance == 0
# 22513                    1.0  height >= 30 AND source_distance == 0
# 22514                    1.0  height >= 30 AND source_distance == 0
# 22515                    1.0  height >= 30 AND source_distance == 0
# 22516                    1.0  height >= 30 AND source_distance == 0
#
#                              Shared Then DNF  Penality Then  \
# 0      height >= 30 AND source_distance == 0            0.0
# 1      height >= 30 AND source_distance == 0            0.0
# 2      height >= 30 AND source_distance == 0            0.0
# 3      height >= 30 AND source_distance == 0            0.0
# 4      height >= 30 AND source_distance == 0            0.0
# ...                                      ...            ...
# 22512  height >= 30 AND source_distance == 0            0.0
# 22513  height >= 30 AND source_distance == 0            0.0
# 22514  height >= 30 AND source_distance == 0            0.0
# 22515  height >= 30 AND source_distance == 0            0.0
# 22516  height >= 30 AND source_distance == 0            0.0
#
#        Global Similarity Then  Final Similarity Then  Scenario Similarity  \
# 0                         1.0                    1.0             1.000000
# 1                         1.0                    1.0             0.969697
# 2                         1.0                    1.0             0.969697
# 3                         1.0                    1.0             0.969697
# 4                         1.0                    1.0             0.969697
# ...                       ...                    ...                  ...
# 22512                     1.0                    1.0             0.697248
# 22513                     1.0                    1.0             0.697248
# 22514                     1.0                    1.0             0.697248
# 22515                     1.0                    1.0             0.697248
# 22516                     1.0                    1.0             0.697248
#
#             Action
# 0       behavior_1
# 1      behavior_12
# 2      behavior_21
# 3      behavior_20
# 4      behavior_19
# ...            ...
# 22512   behavior_8
# 22513   behavior_9
# 22514  behavior_10
# 22515  behavior_11
# 22516   behavior_1
#
# [22517 rows x 19 columns]

# %%
#df=results_for_scenario[0]["Desired"]
df = all_similarities_df.reset_index(drop=True)
## df.to_csv(f"res/outcome/similarities/{shared_base_name}_results.csv", index=False, sep=';', decimal=',')
df.to_csv(f"res/outcome/similarities/{shared_base_name}_results.csv", index=False, sep=';')
