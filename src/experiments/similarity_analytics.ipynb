# %%
#TODO nao estou tratanto o caso do OR
#TODO nao nao trado caso o usario queira colocar um intervalor tipo assim 30<=var<=40

# %%
shared_base_name = "RQ1_shared_scenarios"

# %%
variables_config_path = "res/variables_config.json"

shared_base_path = f"res/outcome/shared_scenarios/{shared_base_name}.json"
analyzed_scenarios_path ="res/analyzed_scenario_process.json"

# %%
import json
import pandas as pd
from pyparsing import Word, alphas, nums, oneOf, infixNotation, opAssoc, ParserElement
from sympy import sympify
from sympy.logic.boolalg import to_dnf
import re
# Configurações para exibir todas as colunas
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
def get_desired_scenario(file_path=analyzed_scenarios_path):
    # Ler o arquivo JSON
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Pegar o valor da chave 'desired'
    desired_scenarios = data.get('desired')
    # desired_scenario_name = next(iter(desired_scenario))
    # Exibir o valor

    # print("Desired scenario: ", desired_scenario)
    
    return desired_scenarios

# get_desired_scenario()

# %%
def load_variable_ranges(file_path = variables_config_path):
    with open(file_path, 'r') as file:
        json_data = file.read()
    variable_ranges = json.loads(json_data)
    
    # print("Variable ranges: ", {var['name']: var for var in variable_ranges})

    return {var['name']: var for var in variable_ranges}

# load_variable_ranges()

# %%
def get_shared_scenarios(file_path = shared_base_path):
    # Ler o arquivo JSON
    with open(file_path, 'r') as file:
        shared_scenarios = json.load(file)
    return shared_scenarios

# %%
def get_Given(scenario):
   # print("Scenario: ",scenario)
    scenario_name = next(iter(scenario))
    given_exp=scenario[scenario_name]["Given"]
  #  print("Given: ",given_exp)
    return given_exp

# print(get_Given(get_desired_scenario()))

# %%
def get_Do(scenario):
    scenario_name = next(iter(scenario))  
    do_exp=scenario[scenario_name]["Do"]
    # print("Do: ",do_exp)
    return do_exp

# %%
def get_When(scenario):
    scenario_name = next(iter(scenario))  
    when_exp=scenario[scenario_name]["When"]
    # print("When: ", when_exp)
    return when_exp

# print(get_When(get_desired_scenario()))

# %%
def get_Then(scenario):
    scenario_name = next(iter(scenario)) 
    then_exp=scenario[scenario_name]["Then"]
    # print("Then: ", then_exp)
    return then_exp

# print(get_Then(get_desired_scenario()))

# %%
def get_precondition(scenario):
    print("Scenario: ", scenario)
    given_exp=get_Given(scenario)
    when_exp=get_When(scenario)

    precond = "{} AND {}".format(given_exp, when_exp)
    # print(f"Precondition: {precond}")
    return precond

# print(get_precondition(get_desired_scenario()))

# %%
def get_postcondition(scenario):

    postcond =  get_Then(scenario)
    # print(f"Postcondition: {postcond}")
    return postcond

# print(get_postcondition(get_desired_scenario()))

# %%
def logical_expression_settings():
    # Configurar pyparsing para ignorar espaços em branco
    ParserElement.enablePackrat()

    # Definir elementos básicos da expressão
    identifier = Word(alphas, alphas + nums + "_")
    number = Word(nums)

    # Definir operadores de comparação
    comparison_operator = oneOf("<= >= < > == !=")

    # Definir expressão básica
    operand = identifier | number

    # Definir expressão lógica
    logical_expr = infixNotation(operand,
        [
            (comparison_operator, 2, opAssoc.LEFT),
            ("AND", 2, opAssoc.LEFT),
            ("OR", 2, opAssoc.LEFT),
        ])

    return logical_expr


def extract_leaves(parsed_expr):
    """Extrai folhas de uma expressão lógica analisada."""
    
    if isinstance(parsed_expr, str):
        return []
    elif len(parsed_expr) == 3 and parsed_expr[1] in ["<=", ">=", "<", ">", "==", "!="]:
        return [" ".join(parsed_expr)]
    else:
        leaves = []
        for sub_expr in parsed_expr:
            leaves.extend(extract_leaves(sub_expr))
        return leaves

# Exemplo de uso
# expression_scenario = "(((a <= 3 AND (b > 10 OR c == 10)) OR ((d != 5 AND e >= 20) OR f < 2)) AND ((g <= 7 OR h > 8) AND (i == 9 OR j != 3)))"
# expression_scenario = "(a <= 3 AND b > 10)"

# expression_scenario = get_Given(get_desired_scenario())

# parsed_expression = logical_expression_settings().parseString(expression_scenario, parseAll=True)

# print("Extracted Leafs:", extract_leaves(parsed_expression.asList()))

# %%
def list_to_indexed_dict(lst):
    """
    Transforms a list of strings into a dictionary with keys 'x1', 'x2', ..., 'xn'.
    
    Parameters:
    lst (list): List of strings.

    Returns:
    dict: Dictionary with keys 'x1', 'x2', ..., 'xn' and values from the original list.
    """
    return {f'x{i+1}': value for i, value in enumerate(lst)}

# Example usage
# lst = ['a <= 3', 'b > 10']
# map_dict = list_to_indexed_dict(extract_leaves(parsed_expression.asList()))
# print("Indexed Dict:", map_dict)

# %%
def replace_values_with_keys(string, dictionary):
    """
    Replaces occurrences of the dictionary values with the keys in the string.

    Parameters:
    string (str): The string where the replacements will be made.
    dictionary (dict): The dictionary with keys and values to be replaced.

    Returns:
    str: The string with values replaced by keys.
    """
    for key, value in dictionary.items():
        string = string.replace(value, key)
    return string

# indexed_scenario = replace_values_with_keys(expression_scenario, map_dict)
# print(indexed_scenario)

# %%
def replace_logical_operators(string, scenario_operators=False):
    """
    Substitui os operadores lógicos 'AND' por '&' e 'OR' por '|', ou vice-versa.

    Parâmetros:
    string (str): A string onde as substituições serão feitas.
    scenario_operators (bool): Se True, substitui '&' por 'AND' e '|' por 'OR'.
                               Se False, substitui 'AND' por '&' e 'OR' por '|'.

    Retorno:
    str: A string com os operadores lógicos substituídos.
    """
    if scenario_operators:
        return string.replace('&', 'AND').replace('|', 'OR')
    else:
        return string.replace('AND', '&').replace('OR', '|')



# indexed_scenario = replace_logical_operators(indexed_scenario)
# print("indexed_scenario:", indexed_scenario)

# %%
def _to_dnf(indexed_scenario):
    """
    Converts a logical expression to Disjunctive Normal Form (DNF).

    Parameters:
    indexed_scenario (str): The logical expression in string format with indexed variables.

    Returns:
    str: The logical expression in Disjunctive Normal Form.
    """
    # Convert the string to a symbolic expression
    logical_expression = sympify(indexed_scenario)

    # Convert the symbolic expression to Disjunctive Normal Form
    dnf_expr = to_dnf(logical_expression, simplify=True, force=True)

    return str(dnf_expr)

# Example usage
# dnf_expr = __to_dnf_expression(indexed_scenario)
# print(dnf_expr)

# %%
def revert_keys_to_values(string, dictionary):
    """
    Replaces occurrences of the dictionary keys with the values in the string.

    Parameters:
    string (str): The string where the replacements will be made.
    dictionary (dict): The dictionary with keys and values to be replaced.

    Returns:
    str: The string with the keys replaced by the original values.
    """
    # print("Dictionary: ", dictionary)
    for key, value in dictionary.items():
        string = re.sub(rf'\b{re.escape(key)}\b', value, string)    
        # string = string.replace(key, value)
    
    return string

# Example usage
# final_string = revert_keys_to_values(str(dnf_expr), map_dict)
# print(f"Final string with original values: {final_string}")

# %%
def to_dnf_expression(expression_scenario):

    parsed_expression = logical_expression_settings().parseString(expression_scenario, parseAll=True)
    # print("Parsed Expression:", parsed_expression)

    extracted_leaves=extract_leaves(parsed_expression.asList())
    # print("Extracted Leafs:", extracted_leaves)

    map_dict = list_to_indexed_dict(extracted_leaves)
    # print("Indexed Dict:", map_dict)

    indexed_scenario = replace_values_with_keys(expression_scenario, map_dict)
    # print("replaced values with keys:", indexed_scenario)

    indexed_scenario = replace_logical_operators(indexed_scenario)
    # print("indexed_scenario:", indexed_scenario)

    dnf_expr = _to_dnf(indexed_scenario)
    # print(dnf_expr)

    # Example usage
    dnf_expression = revert_keys_to_values(str(dnf_expr), map_dict)
    # print(f"Final string with original values: {dnf_expression}")

    dnf_expression=replace_logical_operators(dnf_expression, scenario_operators=True)
    # print(f"dnf_expression: {dnf_expression}")

    return dnf_expression

# %%
def parse_expression(leaf):
    """
    Parse the expression into its components: variable, operator, and value.
    """
    match = re.match(r"(\w+)\s*(>=|<=|>|<|==|!=)\s*(.+)", leaf)
    if match:
        variable, operator, value = match.groups()
        return variable, operator, value
    else:
        raise ValueError(f"Invalid expression format: {leaf}")

def get_expression_range(var_name, operator, value, min_val, max_val):
    """
    Determine the range of values that satisfy the expression.
    """
    value = float(value)
    if operator == '>=':
        return (value, max_val)
    elif operator == '<=':
        return (min_val, value)
    elif operator == '>':
        return (value + 1e-9, max_val)  # Adding a small value to make it exclusive
    elif operator == '<':
        return (min_val, value - 1e-9)  # Subtracting a small value to make it exclusive
    elif operator == '==':
        return (value, value)
    elif operator == '!=':
        return [(min_val, value - 1e-9), (value + 1e-9, max_val)]  # Returns two ranges
    else:
        raise ValueError(f"Unsupported operator: {operator}")

def calculate_jaccard_similarity(leaf1, leaf2, variable_ranges):
    """
    Calculate the Jaccard similarity between two expressions.
    The expressions should be of the format: "variable operator value".
    """
    try:
        var1, op1, val1 = parse_expression(leaf1)
        var2, op2, val2 = parse_expression(leaf2)
    except ValueError as e:
        print(e)
        return 0.0

    # Ensure the variable names are the same
    if var1 != var2:
        return 0.0

    # Get variable ranges
    var_info = variable_ranges.get(var1)
    if not var_info:
        print(f"Variable {var1} not found in ranges.")
        return 0.0

    min_val = var_info['min_value']
    max_val = var_info['max_value']

    # Get ranges for each expression
    range1 = get_expression_range(var1, op1, val1, min_val, max_val)
    range2 = get_expression_range(var2, op2, val2, min_val, max_val)

    def calculate_intersection_union(range1, range2):
        """
        Helper function to calculate intersection and union of two ranges.
        """
        if isinstance(range1, list):
            intersections = []
            for r1 in range1:
                if isinstance(range2, list):
                    for r2 in range2:
                        intersections.append((max(r1[0], r2[0]), min(r1[1], r2[1])))
                else:
                    intersections.append((max(r1[0], range2[0]), min(r1[1], range2[1])))
        else:
            if isinstance(range2, list):
                intersections = [(max(range1[0], r2[0]), min(range1[1], r2[1])) for r2 in range2]
            else:
                intersections = [(max(range1[0], range2[0]), min(range1[1], range2[1]))]
        
        valid_intersections = [r for r in intersections if r[0] <= r[1]]
        intersection_length = sum(r[1] - r[0] for r in valid_intersections)
        
        union_min = min(range1[0] if not isinstance(range1, list) else min(r[0] for r in range1),
                        range2[0] if not isinstance(range2, list) else min(r[0] for r in range2))
        union_max = max(range1[1] if not isinstance(range1, list) else max(r[1] for r in range1),
                        range2[1] if not isinstance(range2, list) else max(r[1] for r in range2))
        union_length = union_max - union_min
        
        return intersection_length, union_length

    # Calculate intersection and union considering the equality operator cases
    if op1 == '==' and op2 != '==':
        if isinstance(range2, list):
            range2_min, range2_max = min(range2[0][0], range2[1][0]), max(range2[0][1], range2[1][1])
            if range2_min <= range1[0] <= range2_max:
                intersection_length = 1
                union_length = range2_max - range2_min
            else:
                return 0.0
        else:
            if range2[0] <= range1[0] <= range2[1]:
                intersection_length = 1
                union_length = range2[1] - range2[0]
            else:
                return 0.0
    elif op2 == '==' and op1 != '==':
        if isinstance(range1, list):
            range1_min, range1_max = min(range1[0][0], range1[1][0]), max(range1[0][1], range1[1][1])
            if range1_min <= range2[0] <= range1_max:
                intersection_length = 1
                union_length = range1_max - range1_min
            else:
                return 0.0
        else:
            if range1[0] <= range2[0] <= range1[1]:
                intersection_length = 1
                union_length = range1[1] - range1[0]
            else:
                return 0.0
    elif op1 == '==' and op2 == '==':
        if val1 == val2:
            return 1.0
        else:
            return 0.0
    else:
        intersection_length, union_length = calculate_intersection_union(range1, range2)

    # Calculate the Jaccard similarity

    if union_length == 0:
        return 0.0
    similarity = intersection_length / union_length
    return round(similarity,5)

# Load the variable ranges from the file
variable_ranges_from_file = load_variable_ranges()

# Test cases
test_cases = [
    # ("height == 30", "height <= 40"),  # equality with range
    # ("height == 30", "height == 30"),  # equality with equality (same)
    # ("height == 30", "height == 40"),  # equality with equality (different)
    # ("height >= 30", "height <= 40"),  # range with range
    # ("height != 30", "height <= 40"),  # inequality with range
    # ("battery < 10", "battery < 11"),
    # ("battery < 10", "battery > 11"),
    # ("battery < 10", "battery > 0"),
    # ("wind_speed <= 36", "wind_speed <= 360"),
    # ("wind_speed <= 36", "wind_speed >= 0"),
    ("wind_speed <= 36","wind_speed > 36")
       # inequality with equality
]

var_similarity_dict = {f"{expr1} vs {expr2}": calculate_jaccard_similarity(expr1, expr2, variable_ranges_from_file)
           for expr1, expr2 in test_cases}

# # Convert results to DataFrame and display
# results_df = pd.DataFrame(results.items(), columns=["Test Case", "Similarity"])
# results_df
var_similarity_dict
# Out:
# {'wind_speed <= 36 vs wind_speed > 36': 0.0}

# %%
# calculate_jaccard_similarity('obstacle > 10', 'obstacle < 11', load_variable_ranges())

# %%
def local_similarity(leaf1, leaf2, variable_ranges_from_file):
    local_similarity = calculate_jaccard_similarity(leaf1, leaf2, variable_ranges_from_file)
    # print(f"Local similarity between {leaf1} vs {leaf2}: {local_similarity}")
    return local_similarity

# %%
def get_leafs(dnf):
    parsed_expression = logical_expression_settings().parseString(dnf, parseAll=True)
    # print("Parsed Expression:", parsed_expression)

    extracted_leaves=extract_leaves(parsed_expression.asList())
    # print("Extracted Leafs:", extracted_leaves)
    return extracted_leaves

# %%
def extract_variables(leafts):
    """
    Extracts the variable names from a list of leaf strings.

    Parameters:
    leaves (list): List of strings, each containing a variable, an operator, and a value.

    Returns:
    list: List of variable names.
    """
    variables = []
    for leaf in leafts:
        # Using regular expression to match the variable name at the beginning of the string
        match = re.match(r"([a-zA-Z_]\w*)\s*(==|!=|[<>]=?)\s*\d+", leaf)
        if match:
            variables.append(match.group(1))
    return variables

# %%
def tversky_similarity(vars1, vars2, alpha=1.0, beta=1.0):
    """
    Calculate the Tversky similarity between two sets of variables.
    
    Args:
    vars1 (list): First list of variables.
    vars2 (list): Second list of variables.
    alpha (float): Weight for the elements unique to vars1. Default is 1.0.
    beta (float): Weight for the elements unique to vars2. Default is 1.0.
    
    Returns:
    float: The Tversky similarity score.
    """
    set1 = set(vars1)
    set2 = set(vars2)
    
    intersection = len(set1 & set2)
    only_in_set1 = len(set1 - set2)
    only_in_set2 = len(set2 - set1)
    
    tversky_index = intersection / (intersection + alpha * only_in_set1 + beta * only_in_set2)
    
    return tversky_index

def penality(vars1, vars2, alpha=1.0, beta=1.0):
    return 1 - tversky_similarity(vars1, vars2, alpha, beta)

# %%
def intersection(vector1, vector2):
    """
    Find the intersection between two vectors of elements.
    
    Args:
    vector1 (list): First list of elements.
    vector2 (list): Second list of elements.
    
    Returns:
    list: A list containing the elements that are present in both vectors.
    """
    set1 = set(vector1)
    set2 = set(vector2)
    
    intersection = set1 & set2
    
    return list(intersection)

# %%
def pair_leaves(leaves1, leaves2):
    """
    Create pairs of leaves containing the same variable.
    
    Args:
    leaves1 (list): First list of leaves.
    leaves2 (list): Second list of leaves.
    
    Returns:
    list: A list of tuples, each containing a pair of leaves with the same variable.
    """
    pairs = []
    
    # Extract variable names from leaves
    def extract_variable(leaf):
        return leaf.split()[0]
    
    variables1 = {extract_variable(leaf): leaf for leaf in leaves1}
    variables2 = {extract_variable(leaf): leaf for leaf in leaves2}
    
    # Create pairs
    for var in variables1:
        if var in variables2:
            pairs.append((variables1[var], variables2[var]))
    
    return pairs

# %%
# funcao Mocked para similar os pesos.
def get_weights():
    # TODO: Implementar a lógica para obter os pesos com esse formato {'a': 0.75, 'b': 0.0, 'c': 0.0}
    return {} # Weight is considered 1 when variable is not present in the weights dictionary

weight_dict = get_weights()
# print("Weights:{}".format(weight_dict))

# %%
def extract_variable_similarity(local_similarity):
    """
    Extract variable names and their similarities from a dictionary of leaf pairs.
    
    Args:
    pairs_similarity (dict): A dictionary with tuples of leaf pairs as keys and similarity values as values.
    
    Returns:
    dict: A dictionary with variable names as keys and similarity values as values.
    """
    variable_similarity = {}
    
    for (leaf1, leaf2), similarity in local_similarity.items():
        variable = leaf1.split()[0]
        variable_similarity[variable] = similarity
    
    return variable_similarity

# %%
def similarity_global(local_similarity):
    weight_dict=get_weights()
    variable_similarity_dict=extract_variable_similarity(local_similarity)

    weighted_sum = 0
    total_weight = 0
    
    for var, similarity in variable_similarity_dict.items():
        weight = weight_dict.get(var, 1)
        weighted_sum += similarity * weight
        total_weight += weight

    if total_weight == 0:
        return 0  # Avoid division by zero
    
    weighted_average = weighted_sum / total_weight
    return weighted_average

# %%
def scenario_similarity(final_similarity_given,
                         final_similarity_when,
                           final_similarity_then,
                           weight_given=1.0,weight_when=1.0,weight_then=1.0):
    return (final_similarity_given * weight_given + final_similarity_when * weight_when + final_similarity_then * weight_then) / (weight_given + weight_when + weight_then)

# %%
def similarity(desired_scenario):
    given_dnf1=to_dnf_expression(get_Given(desired_scenario))
    when_dnf1=to_dnf_expression(get_When(desired_scenario))
    then_dnf1=to_dnf_expression(get_Then(desired_scenario))

    shared_scenarios = get_shared_scenarios()

    # Lista para armazenar os resultados
    results_to_df = []

    similarity_result = {} 
    for shared_scenario in shared_scenarios:

        # print("Desired Given DNF: ", given_dnf1)
        # print("Desired When DNF: ", when_dnf1)
        # print("Desired Then DNF: ", then_dnf1)
        # print("")

        given_leafs1=get_leafs(given_dnf1)
        when_leafs1=get_leafs(when_dnf1)
        then_leafs1=get_leafs(then_dnf1)

        # print("Leafs Given 1: ", given_leafs1)
        # print("Leafs When 1: ", when_leafs1)
        # print("Leafs Then 1: ", then_leafs1)

        given_variables1=extract_variables(given_leafs1)
        when_variables1=extract_variables(when_leafs1)
        then_variables1=extract_variables(then_leafs1)

        # print("Variables Given 1: ", given_variables1)
        # print("Variables When 1: ", when_variables1)
        # print("Variables Then 1: ", then_variables1)

        # print("---")
        scenario_name = next(iter(shared_scenario))

        # print("Shared Scenario: ", scenario_name)

        given_dnf2=to_dnf_expression(get_Given(shared_scenario))
        when_dnf2=to_dnf_expression(get_When(shared_scenario))
        do2=to_dnf_expression(get_Do(shared_scenario))
        then_dnf2=to_dnf_expression(get_Then(shared_scenario))

        # print("Shared Given DNF: ", given_dnf2)
        # print("Shared When DNF: ", when_dnf2)
        # print("Shared Do: ", do2)
        # print("Shared Then DNF: ", then_dnf2)
        # print("")

        given_leafs2=get_leafs(given_dnf2)
        when_leafs2=get_leafs(when_dnf2)
        then_leafs2=get_leafs(then_dnf2)

        # print("Leafs Given 2: ", given_leafs2)
        # print("Leafs When 2: ", when_leafs2)
        # print("Leafs Then 2: ", then_leafs2)
        # print("")
        given_variables2=extract_variables(given_leafs2)
        when_variables2=extract_variables(when_leafs2)
        then_variables2=extract_variables(then_leafs2)

        # print("Variables Given 2: ", given_variables2)
        # print("Variables When 2: ", when_variables2)
        # print("Variables Then 2: ", then_variables2)
        # print("")

        penality_given=penality(given_variables1, given_variables2, alpha=0.9, beta=0.1)
        penality_when=penality(when_variables1, when_variables2, alpha=0.9, beta=0.1)
        penality_then=penality(then_variables1, then_variables2, alpha=0.9, beta=0.1)

        # print("Penality Given: ", penality_given)
        # print("Penality When: ", penality_when)
        # print("Penality Then: ", penality_then)
        # print("")

        pair_leaves_given=pair_leaves(given_leafs1, given_leafs2)
        pair_leaves_when=pair_leaves(when_leafs1, when_leafs2)
        pair_leaves_then=pair_leaves(then_leafs1, then_leafs2)

        # print("Pair Leaves Given: ", pair_leaves_given)
        # print("Pair Leaves When: ", pair_leaves_when)
        # print("Pair Leaves Then: ", pair_leaves_then)
        # print("")

        given_local_similarity_result={}
        when_local_similarity_result={}
        then_local_similarity_result={}

        for pair in pair_leaves_given:
            given_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())

        for pair in pair_leaves_when:
            when_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())

        for pair in pair_leaves_then:
            then_local_similarity_result[pair]=local_similarity(pair[0], pair[1], load_variable_ranges())


        # print("Given Local Similarity Result: ", given_local_similarity_result)
        # print("When Local Similarity Result: ", when_local_similarity_result)
        # print("Then Local Similarity Result: ", then_local_similarity_result)
        # print("")

        global_similarity_given=similarity_global(given_local_similarity_result)
        global_similarity_when=similarity_global(when_local_similarity_result)
        global_similarity_then=similarity_global(then_local_similarity_result)

        # print("Global Similarity Given: ", global_similarity_given)
        # print("Global Similarity When: ", global_similarity_when)
        # print("Global Similarity Then: ", global_similarity_then)
        # print("")
        
        final_similarity_given=global_similarity_given-penality_given
        final_similarity_when=global_similarity_when-penality_when
        final_similarity_then=global_similarity_then-penality_then

        # print("Final Similarity Given: ", final_similarity_given)
        # print("Final Similarity When: ", final_similarity_when)
        # print("Final Similarity Then: ", final_similarity_then)
        # print("")

        scenario_similarity_result=scenario_similarity(final_similarity_given,
                                                        final_similarity_when,
                                                        final_similarity_then,
                                                        weight_given=1.0,
                                                        weight_when=1.0,
                                                        weight_then=1.0)

        # print("Scenario Similarity: ", scenario_similarity_result)
        # print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")

        # Adiciona os resultados ao DataFrame
        results_to_df.append({
                "Scenario": scenario_name,
                "Desired Given DNF": given_dnf1,
                "Shared Given DNF": given_dnf2,
                # "Desired Given Variables": given_variables1,
                # "Shared Given Variables": given_variables2,
                "Penality Given": penality_given,
                "Global Similarity Given": global_similarity_given,
                "Final Similarity Given": final_similarity_given,
                "Desired When DNF": when_dnf1,
                "Shared When DNF": when_dnf2,
                # "Desired When Variables": when_variables1,
                # "Shared When Variables": when_variables2,
                "Penality When": penality_when,
                "Global Similarity When": global_similarity_when,
                "Final Similarity When": final_similarity_when,
                "Desired Then DNF": then_dnf1,
                "Shared Then DNF": then_dnf2,
                # "Desired Then Variables": then_variables1,
                # "Shared Then Variables": then_variables2,
                "Penality Then": penality_then,
                "Global Similarity Then": global_similarity_then,
                "Final Similarity Then": final_similarity_then,
                "Scenario Similarity": scenario_similarity_result,
                "Action": do2
            })
        

    # Cria o DataFrame
    df_results = pd.DataFrame(results_to_df).sort_values(by="Scenario Similarity", ascending=False)
    df_results = df_results.reset_index(drop=True)

    return df_results

# %%
desired_scenarios=get_desired_scenario()

# %%
desired_scenarios
# Out:
# [{'Desired_1': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_1',
#    'Then': 'height >= 30'}},
#  {'Desired_2': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_2',
#    'Then': 'source_distance == 0'}},
#  {'Desired_3': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_3',
#    'Then': 'a > 10'}},
#  {'Desired_4': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_4',
#    'Then': 'b > 10'}},
#  {'Desired_5': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_5',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_6': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_6',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_7': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_7',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_8': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_8',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_9': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_9',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_10': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_10',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_11': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_11',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_12': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_12',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_13': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_13',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_14': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_14',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_15': {'Given': 'battery >= 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_15',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_16': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_16',
#    'Then': 'height >= 30'}},
#  {'Desired_17': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_17',
#    'Then': 'source_distance == 0'}},
#  {'Desired_18': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_18',
#    'Then': 'a > 10'}},
#  {'Desired_19': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_19',
#    'Then': 'b > 10'}},
#  {'Desired_20': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_20',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_21': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_21',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_22': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_22',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_23': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_23',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_24': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_24',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_25': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_25',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_26': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_26',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_27': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_27',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_28': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_28',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_29': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_29',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_30': {'Given': 'satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_30',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_31': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_31',
#    'Then': 'height >= 30'}},
#  {'Desired_32': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_32',
#    'Then': 'source_distance == 0'}},
#  {'Desired_33': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_33',
#    'Then': 'a > 10'}},
#  {'Desired_34': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_34',
#    'Then': 'b > 10'}},
#  {'Desired_35': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_35',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_36': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_36',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_37': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_37',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_38': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_38',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_39': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_39',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_40': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_40',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_41': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_41',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_42': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_42',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_43': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_43',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_44': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_44',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_45': {'Given': 'wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_45',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_46': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_46',
#    'Then': 'height >= 30'}},
#  {'Desired_47': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_47',
#    'Then': 'source_distance == 0'}},
#  {'Desired_48': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_48',
#    'Then': 'a > 10'}},
#  {'Desired_49': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_49',
#    'Then': 'b > 10'}},
#  {'Desired_50': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_50',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_51': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_51',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_52': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_52',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_53': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_53',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_54': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_54',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_55': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_55',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_56': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_56',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_57': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_57',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_58': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_58',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_59': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_59',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_60': {'Given': 'a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_60',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_61': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_61',
#    'Then': 'height >= 30'}},
#  {'Desired_62': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_62',
#    'Then': 'source_distance == 0'}},
#  {'Desired_63': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_63',
#    'Then': 'a > 10'}},
#  {'Desired_64': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_64',
#    'Then': 'b > 10'}},
#  {'Desired_65': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_65',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_66': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_66',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_67': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_67',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_68': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_68',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_69': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_69',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_70': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_70',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_71': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_71',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_72': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_72',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_73': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_73',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_74': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_74',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_75': {'Given': 'b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_75',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_76': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_76',
#    'Then': 'height >= 30'}},
#  {'Desired_77': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_77',
#    'Then': 'source_distance == 0'}},
#  {'Desired_78': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_78',
#    'Then': 'a > 10'}},
#  {'Desired_79': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_79',
#    'Then': 'b > 10'}},
#  {'Desired_80': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_80',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_81': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_81',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_82': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_82',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_83': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_83',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_84': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_84',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_85': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_85',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_86': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_86',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_87': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_87',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_88': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_88',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_89': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_89',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_90': {'Given': 'battery >= 10 AND satellite_count >= 7',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_90',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_91': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_91',
#    'Then': 'height >= 30'}},
#  {'Desired_92': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_92',
#    'Then': 'source_distance == 0'}},
#  {'Desired_93': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_93',
#    'Then': 'a > 10'}},
#  {'Desired_94': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_94',
#    'Then': 'b > 10'}},
#  {'Desired_95': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_95',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_96': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_96',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_97': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_97',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_98': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_98',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_99': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_99',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_100': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_100',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_101': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_101',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_102': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_102',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_103': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_103',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_104': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_104',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_105': {'Given': 'battery >= 10 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_105',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_106': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_106',
#    'Then': 'height >= 30'}},
#  {'Desired_107': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_107',
#    'Then': 'source_distance == 0'}},
#  {'Desired_108': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_108',
#    'Then': 'a > 10'}},
#  {'Desired_109': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_109',
#    'Then': 'b > 10'}},
#  {'Desired_110': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_110',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_111': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_111',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_112': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_112',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_113': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_113',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_114': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_114',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_115': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_115',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_116': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_116',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_117': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_117',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_118': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_118',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_119': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_119',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_120': {'Given': 'battery >= 10 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_120',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_121': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_121',
#    'Then': 'height >= 30'}},
#  {'Desired_122': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_122',
#    'Then': 'source_distance == 0'}},
#  {'Desired_123': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_123',
#    'Then': 'a > 10'}},
#  {'Desired_124': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_124',
#    'Then': 'b > 10'}},
#  {'Desired_125': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_125',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_126': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_126',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_127': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_127',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_128': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_128',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_129': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_129',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_130': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_130',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_131': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_131',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_132': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_132',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_133': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_133',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_134': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_134',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_135': {'Given': 'battery >= 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_135',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_136': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_136',
#    'Then': 'height >= 30'}},
#  {'Desired_137': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_137',
#    'Then': 'source_distance == 0'}},
#  {'Desired_138': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_138',
#    'Then': 'a > 10'}},
#  {'Desired_139': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_139',
#    'Then': 'b > 10'}},
#  {'Desired_140': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_140',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_141': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_141',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_142': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_142',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_143': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_143',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_144': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_144',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_145': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_145',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_146': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_146',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_147': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_147',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_148': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_148',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_149': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_149',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_150': {'Given': 'satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_150',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_151': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_151',
#    'Then': 'height >= 30'}},
#  {'Desired_152': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_152',
#    'Then': 'source_distance == 0'}},
#  {'Desired_153': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_153',
#    'Then': 'a > 10'}},
#  {'Desired_154': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_154',
#    'Then': 'b > 10'}},
#  {'Desired_155': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_155',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_156': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_156',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_157': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_157',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_158': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_158',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_159': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_159',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_160': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_160',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_161': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_161',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_162': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_162',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_163': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_163',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_164': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_164',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_165': {'Given': 'satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_165',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_166': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_166',
#    'Then': 'height >= 30'}},
#  {'Desired_167': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_167',
#    'Then': 'source_distance == 0'}},
#  {'Desired_168': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_168',
#    'Then': 'a > 10'}},
#  {'Desired_169': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_169',
#    'Then': 'b > 10'}},
#  {'Desired_170': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_170',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_171': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_171',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_172': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_172',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_173': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_173',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_174': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_174',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_175': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_175',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_176': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_176',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_177': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_177',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_178': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_178',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_179': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_179',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_180': {'Given': 'satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_180',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_181': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_181',
#    'Then': 'height >= 30'}},
#  {'Desired_182': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_182',
#    'Then': 'source_distance == 0'}},
#  {'Desired_183': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_183',
#    'Then': 'a > 10'}},
#  {'Desired_184': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_184',
#    'Then': 'b > 10'}},
#  {'Desired_185': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_185',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_186': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_186',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_187': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_187',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_188': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_188',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_189': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_189',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_190': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_190',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_191': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_191',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_192': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_192',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_193': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_193',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_194': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_194',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_195': {'Given': 'wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_195',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_196': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_196',
#    'Then': 'height >= 30'}},
#  {'Desired_197': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_197',
#    'Then': 'source_distance == 0'}},
#  {'Desired_198': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_198',
#    'Then': 'a > 10'}},
#  {'Desired_199': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_199',
#    'Then': 'b > 10'}},
#  {'Desired_200': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_200',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_201': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_201',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_202': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_202',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_203': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_203',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_204': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_204',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_205': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_205',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_206': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_206',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_207': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_207',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_208': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_208',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_209': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_209',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_210': {'Given': 'wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_210',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_211': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_211',
#    'Then': 'height >= 30'}},
#  {'Desired_212': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_212',
#    'Then': 'source_distance == 0'}},
#  {'Desired_213': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_213',
#    'Then': 'a > 10'}},
#  {'Desired_214': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_214',
#    'Then': 'b > 10'}},
#  {'Desired_215': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_215',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_216': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_216',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_217': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_217',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_218': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_218',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_219': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_219',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_220': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_220',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_221': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_221',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_222': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_222',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_223': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_223',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_224': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_224',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_225': {'Given': 'a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_225',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_226': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_226',
#    'Then': 'height >= 30'}},
#  {'Desired_227': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_227',
#    'Then': 'source_distance == 0'}},
#  {'Desired_228': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_228',
#    'Then': 'a > 10'}},
#  {'Desired_229': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_229',
#    'Then': 'b > 10'}},
#  {'Desired_230': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_230',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_231': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_231',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_232': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_232',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_233': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_233',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_234': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_234',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_235': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_235',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_236': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_236',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_237': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_237',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_238': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_238',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_239': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_239',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_240': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_240',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_241': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_241',
#    'Then': 'height >= 30'}},
#  {'Desired_242': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_242',
#    'Then': 'source_distance == 0'}},
#  {'Desired_243': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_243',
#    'Then': 'a > 10'}},
#  {'Desired_244': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_244',
#    'Then': 'b > 10'}},
#  {'Desired_245': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_245',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_246': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_246',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_247': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_247',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_248': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_248',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_249': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_249',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_250': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_250',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_251': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_251',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_252': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_252',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_253': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_253',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_254': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_254',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_255': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_255',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_256': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_256',
#    'Then': 'height >= 30'}},
#  {'Desired_257': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_257',
#    'Then': 'source_distance == 0'}},
#  {'Desired_258': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_258',
#    'Then': 'a > 10'}},
#  {'Desired_259': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_259',
#    'Then': 'b > 10'}},
#  {'Desired_260': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_260',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_261': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_261',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_262': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_262',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_263': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_263',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_264': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_264',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_265': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_265',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_266': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_266',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_267': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_267',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_268': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_268',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_269': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_269',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_270': {'Given': 'battery >= 10 AND satellite_count >= 7 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_270',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_271': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_271',
#    'Then': 'height >= 30'}},
#  {'Desired_272': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_272',
#    'Then': 'source_distance == 0'}},
#  {'Desired_273': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_273',
#    'Then': 'a > 10'}},
#  {'Desired_274': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_274',
#    'Then': 'b > 10'}},
#  {'Desired_275': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_275',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_276': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_276',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_277': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_277',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_278': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_278',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_279': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_279',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_280': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_280',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_281': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_281',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_282': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_282',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_283': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_283',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_284': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_284',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_285': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_285',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_286': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_286',
#    'Then': 'height >= 30'}},
#  {'Desired_287': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_287',
#    'Then': 'source_distance == 0'}},
#  {'Desired_288': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_288',
#    'Then': 'a > 10'}},
#  {'Desired_289': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_289',
#    'Then': 'b > 10'}},
#  {'Desired_290': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_290',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_291': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_291',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_292': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_292',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_293': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_293',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_294': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_294',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_295': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_295',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_296': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_296',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_297': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_297',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_298': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_298',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_299': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_299',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_300': {'Given': 'battery >= 10 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_300',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_301': {'Given': 'battery >= 10 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_301',
#    'Then': 'height >= 30'}},
#  {'Desired_302': {'Given': 'battery >= 10 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_302',
#    'Then': 'source_distance == 0'}},
#  {'Desired_303': {'Given': 'battery >= 10 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_303',
#    'Then': 'a > 10'}},
# ...
#    'Do': 'behavior_384',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_385': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_385',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_386': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_386',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_387': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_387',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_388': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_388',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_389': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_389',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_390': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_390',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_391': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_391',
#    'Then': 'height >= 30'}},
#  {'Desired_392': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_392',
#    'Then': 'source_distance == 0'}},
#  {'Desired_393': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_393',
#    'Then': 'a > 10'}},
#  {'Desired_394': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_394',
#    'Then': 'b > 10'}},
#  {'Desired_395': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_395',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_396': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_396',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_397': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_397',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_398': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_398',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_399': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_399',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_400': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_400',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_401': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_401',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_402': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_402',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_403': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_403',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_404': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_404',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_405': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_405',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_406': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_406',
#    'Then': 'height >= 30'}},
#  {'Desired_407': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_407',
#    'Then': 'source_distance == 0'}},
#  {'Desired_408': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_408',
#    'Then': 'a > 10'}},
#  {'Desired_409': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_409',
#    'Then': 'b > 10'}},
#  {'Desired_410': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_410',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_411': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_411',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_412': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_412',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_413': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_413',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_414': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_414',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_415': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_415',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_416': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_416',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_417': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_417',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_418': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_418',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_419': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_419',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_420': {'Given': 'battery >= 10 AND satellite_count >= 7 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_420',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_421': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_421',
#    'Then': 'height >= 30'}},
#  {'Desired_422': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_422',
#    'Then': 'source_distance == 0'}},
#  {'Desired_423': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_423',
#    'Then': 'a > 10'}},
#  {'Desired_424': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_424',
#    'Then': 'b > 10'}},
#  {'Desired_425': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_425',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_426': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_426',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_427': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_427',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_428': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_428',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_429': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_429',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_430': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_430',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_431': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_431',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_432': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_432',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_433': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_433',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_434': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_434',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_435': {'Given': 'battery >= 10 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_435',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_436': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_436',
#    'Then': 'height >= 30'}},
#  {'Desired_437': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_437',
#    'Then': 'source_distance == 0'}},
#  {'Desired_438': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_438',
#    'Then': 'a > 10'}},
#  {'Desired_439': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_439',
#    'Then': 'b > 10'}},
#  {'Desired_440': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_440',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_441': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_441',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_442': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_442',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_443': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_443',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_444': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_444',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_445': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_445',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_446': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_446',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_447': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_447',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_448': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_448',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_449': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_449',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_450': {'Given': 'satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_450',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_451': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_451',
#    'Then': 'height >= 30'}},
#  {'Desired_452': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_452',
#    'Then': 'source_distance == 0'}},
#  {'Desired_453': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_453',
#    'Then': 'a > 10'}},
#  {'Desired_454': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_454',
#    'Then': 'b > 10'}},
#  {'Desired_455': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_455',
#    'Then': 'height >= 30 AND source_distance == 0'}},
#  {'Desired_456': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_456',
#    'Then': 'height >= 30 AND a > 10'}},
#  {'Desired_457': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_457',
#    'Then': 'height >= 30 AND b > 10'}},
#  {'Desired_458': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_458',
#    'Then': 'source_distance == 0 AND a > 10'}},
#  {'Desired_459': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_459',
#    'Then': 'source_distance == 0 AND b > 10'}},
#  {'Desired_460': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_460',
#    'Then': 'a > 10 AND b > 10'}},
#  {'Desired_461': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_461',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10'}},
#  {'Desired_462': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_462',
#    'Then': 'height >= 30 AND source_distance == 0 AND b > 10'}},
#  {'Desired_463': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_463',
#    'Then': 'height >= 30 AND a > 10 AND b > 10'}},
#  {'Desired_464': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_464',
#    'Then': 'source_distance == 0 AND a > 10 AND b > 10'}},
#  {'Desired_465': {'Given': 'battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10',
#    'When': 'takeoff == 1',
#    'Do': 'behavior_465',
#    'Then': 'height >= 30 AND source_distance == 0 AND a > 10 AND b > 10'}}]

# %%
desired_scenarios=get_desired_scenario()
results_for_scenario = []

for current_desired_scenario in desired_scenarios:
    desired_scenario_name = next(iter(current_desired_scenario))

    df_result=similarity(current_desired_scenario)
    results_for_scenario.append({desired_scenario_name:df_result})

# %%
# juntar tudo em um dataframe só para ficar mais fácil salvar.
all_similarities_df = pd.DataFrame()

for result in results_for_scenario:
    desired_scenario_name = next(iter(result))

    temp_df = result[desired_scenario_name]
    temp_df.insert(0, "desired_scenario",desired_scenario_name)
    temp_df.rename(columns={'Scenario': 'cadidate_scenario'}, inplace=True)

    all_similarities_df = pd.concat([all_similarities_df, temp_df], ignore_index=True)

# %%
all_similarities_df
# Out:
#     desired_scenario cadidate_scenario  \
# 0          Desired_1         candidate
# 1          Desired_2         candidate
# 2          Desired_3         candidate
# 3          Desired_4         candidate
# 4          Desired_5         candidate
# ..               ...               ...
# 460      Desired_461         candidate
# 461      Desired_462         candidate
# 462      Desired_463         candidate
# 463      Desired_464         candidate
# 464      Desired_465         candidate
#
#                                                                      Desired Given DNF  \
# 0                                                                        battery >= 10
# 1                                                                        battery >= 10
# 2                                                                        battery >= 10
# 3                                                                        battery >= 10
# 4                                                                        battery >= 10
# ..                                                                                 ...
# 460  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10
# 461  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10
# 462  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10
# 463  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10
# 464  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36 AND a > 10 AND b > 10
#
#                                                 Shared Given DNF  \
# 0    battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 1    battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 2    battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 3    battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 4    battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# ..                                                           ...
# 460  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 461  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 462  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 463  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
# 464  battery >= 10 AND satellite_count >= 7 AND wind_speed <= 36
#
#      Penality Given  Global Similarity Given  Final Similarity Given  \
# 0          0.166667                      1.0                0.833333
# 1          0.166667                      1.0                0.833333
# 2          0.166667                      1.0                0.833333
# 3          0.166667                      1.0                0.833333
# 4          0.166667                      1.0                0.833333
# ..              ...                      ...                     ...
# 460        0.375000                      1.0                0.625000
# 461        0.375000                      1.0                0.625000
# 462        0.375000                      1.0                0.625000
# 463        0.375000                      1.0                0.625000
# 464        0.375000                      1.0                0.625000
#
#     Desired When DNF Shared When DNF  Penality When  Global Similarity When  \
# 0       takeoff == 1    takeoff == 1            0.0                     1.0
# 1       takeoff == 1    takeoff == 1            0.0                     1.0
# 2       takeoff == 1    takeoff == 1            0.0                     1.0
# 3       takeoff == 1    takeoff == 1            0.0                     1.0
# 4       takeoff == 1    takeoff == 1            0.0                     1.0
# ..               ...             ...            ...                     ...
# 460     takeoff == 1    takeoff == 1            0.0                     1.0
# 461     takeoff == 1    takeoff == 1            0.0                     1.0
# 462     takeoff == 1    takeoff == 1            0.0                     1.0
# 463     takeoff == 1    takeoff == 1            0.0                     1.0
# 464     takeoff == 1    takeoff == 1            0.0                     1.0
#
#      Final Similarity When  \
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# ..                     ...
# 460                    1.0
# 461                    1.0
# 462                    1.0
# 463                    1.0
# 464                    1.0
#
#                                                 Desired Then DNF  \
# 0                                                   height >= 30
# 1                                           source_distance == 0
# 2                                                         a > 10
# 3                                                         b > 10
# 4                          height >= 30 AND source_distance == 0
# ..                                                           ...
# 460             height >= 30 AND source_distance == 0 AND a > 10
# 461             height >= 30 AND source_distance == 0 AND b > 10
# 462                           height >= 30 AND a > 10 AND b > 10
# 463                   source_distance == 0 AND a > 10 AND b > 10
# 464  height >= 30 AND source_distance == 0 AND a > 10 AND b > 10
#
#                            Shared Then DNF  Penality Then  \
# 0    height >= 30 AND source_distance == 0       0.090909
# 1    height >= 30 AND source_distance == 0       0.090909
# 2    height >= 30 AND source_distance == 0       1.000000
# 3    height >= 30 AND source_distance == 0       1.000000
# 4    height >= 30 AND source_distance == 0       0.000000
# ..                                     ...            ...
# 460  height >= 30 AND source_distance == 0       0.310345
# 461  height >= 30 AND source_distance == 0       0.310345
# 462  height >= 30 AND source_distance == 0       0.655172
# 463  height >= 30 AND source_distance == 0       0.655172
# 464  height >= 30 AND source_distance == 0       0.473684
#
#      Global Similarity Then  Final Similarity Then  Scenario Similarity  \
# 0                       1.0               0.909091             0.914141
# 1                       1.0               0.909091             0.914141
# 2                       0.0              -1.000000             0.277778
# 3                       0.0              -1.000000             0.277778
# 4                       1.0               1.000000             0.944444
# ..                      ...                    ...                  ...
# 460                     1.0               0.689655             0.771552
# 461                     1.0               0.689655             0.771552
# 462                     1.0               0.344828             0.656609
# 463                     1.0               0.344828             0.656609
# 464                     1.0               0.526316             0.717105
#
#          Action
# 0    behavior_3
# 1    behavior_3
# 2    behavior_3
# 3    behavior_3
# 4    behavior_3
# ..          ...
# 460  behavior_3
# 461  behavior_3
# 462  behavior_3
# 463  behavior_3
# 464  behavior_3
#
# [465 rows x 19 columns]

# %%
#df=results_for_scenario[0]["Desired"]
df = all_similarities_df.reset_index(drop=True)
## df.to_csv(f"res/outcome/similarities/{shared_base_name}_results.csv", index=False, sep=';', decimal=',')
df.to_csv(f"res/outcome/similarities/{shared_base_name}_results.csv", index=False, sep=';')
